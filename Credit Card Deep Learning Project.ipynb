# %% [markdown]
# <a href="https://colab.research.google.com/github/alteush/Deep-Learning-2024/blob/main/Credit%20Card%20Deep%20Learning%20Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import roc_curve, auc, recall_score
import imblearn
from collections import Counter
from imblearn.over_sampling import SMOTE
from sklearn.model_selection import train_test_split

import tensorflow as tf
from tensorflow import keras

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
from google.colab import drive
drive.mount("/content/drive/")
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
import sys
your_drive_path_to_src_file = "/content/drive/MyDrive/Statistics Masters/Adv. computational learning and data analysis/Project/Data/"
sys.path.append(your_drive_path_to_src_file)

# %%
# original path
# df = pd.read_csv("CSV/creditcard.csv")
df = pd.read_csv("/content/drive/MyDrive/Statistics Masters/Adv. computational learning and data analysis/Project/Data/creditcard.csv")

# %%
df.shape
# Out:
# (284807, 31)

# %%
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
#         V26       V27       V28  Amount  Class
# 0 -0.189115  0.133558 -0.021053  149.62      0
# 1  0.125895 -0.008983  0.014724    2.69      0
# 2 -0.139097 -0.055353 -0.059752  378.66      0
# 3 -0.221929  0.062723  0.061458  123.50      0
# 4  0.502292  0.219422  0.215153   69.99      0
#
# [5 rows x 31 columns]

# %%
df.describe().T
# Out:
#            count          mean           std         min           25%  \
# Time    284807.0  9.481386e+04  47488.145955    0.000000  54201.500000
# V1      284807.0  1.168375e-15      1.958696  -56.407510     -0.920373
# V2      284807.0  3.416908e-16      1.651309  -72.715728     -0.598550
# V3      284807.0 -1.379537e-15      1.516255  -48.325589     -0.890365
# V4      284807.0  2.074095e-15      1.415869   -5.683171     -0.848640
# V5      284807.0  9.604066e-16      1.380247 -113.743307     -0.691597
# V6      284807.0  1.487313e-15      1.332271  -26.160506     -0.768296
# V7      284807.0 -5.556467e-16      1.237094  -43.557242     -0.554076
# V8      284807.0  1.213481e-16      1.194353  -73.216718     -0.208630
# V9      284807.0 -2.406331e-15      1.098632  -13.434066     -0.643098
# V10     284807.0  2.239053e-15      1.088850  -24.588262     -0.535426
# V11     284807.0  1.673327e-15      1.020713   -4.797473     -0.762494
# V12     284807.0 -1.247012e-15      0.999201  -18.683715     -0.405571
# V13     284807.0  8.190001e-16      0.995274   -5.791881     -0.648539
# V14     284807.0  1.207294e-15      0.958596  -19.214325     -0.425574
# V15     284807.0  4.887456e-15      0.915316   -4.498945     -0.582884
# V16     284807.0  1.437716e-15      0.876253  -14.129855     -0.468037
# V17     284807.0 -3.772171e-16      0.849337  -25.162799     -0.483748
# V18     284807.0  9.564149e-16      0.838176   -9.498746     -0.498850
# V19     284807.0  1.039917e-15      0.814041   -7.213527     -0.456299
# V20     284807.0  6.406204e-16      0.770925  -54.497720     -0.211721
# V21     284807.0  1.654067e-16      0.734524  -34.830382     -0.228395
# V22     284807.0 -3.568593e-16      0.725702  -10.933144     -0.542350
# V23     284807.0  2.578648e-16      0.624460  -44.807735     -0.161846
# V24     284807.0  4.473266e-15      0.605647   -2.836627     -0.354586
# V25     284807.0  5.340915e-16      0.521278  -10.295397     -0.317145
# V26     284807.0  1.683437e-15      0.482227   -2.604551     -0.326984
# V27     284807.0 -3.660091e-16      0.403632  -22.565679     -0.070840
# V28     284807.0 -1.227390e-16      0.330083  -15.430084     -0.052960
# Amount  284807.0  8.834962e+01    250.120109    0.000000      5.600000
# Class   284807.0  1.727486e-03      0.041527    0.000000      0.000000
#
#                  50%            75%            max
# Time    84692.000000  139320.500000  172792.000000
# V1          0.018109       1.315642       2.454930
# V2          0.065486       0.803724      22.057729
# V3          0.179846       1.027196       9.382558
# V4         -0.019847       0.743341      16.875344
# V5         -0.054336       0.611926      34.801666
# V6         -0.274187       0.398565      73.301626
# V7          0.040103       0.570436     120.589494
# V8          0.022358       0.327346      20.007208
# V9         -0.051429       0.597139      15.594995
# V10        -0.092917       0.453923      23.745136
# V11        -0.032757       0.739593      12.018913
# V12         0.140033       0.618238       7.848392
# V13        -0.013568       0.662505       7.126883
# V14         0.050601       0.493150      10.526766
# V15         0.048072       0.648821       8.877742
# V16         0.066413       0.523296      17.315112
# V17        -0.065676       0.399675       9.253526
# V18        -0.003636       0.500807       5.041069
# V19         0.003735       0.458949       5.591971
# V20        -0.062481       0.133041      39.420904
# V21        -0.029450       0.186377      27.202839
# V22         0.006782       0.528554      10.503090
# V23        -0.011193       0.147642      22.528412
# V24         0.040976       0.439527       4.584549
# V25         0.016594       0.350716       7.519589
# V26        -0.052139       0.240952       3.517346
# V27         0.001342       0.091045      31.612198
# V28         0.011244       0.078280      33.847808
# Amount     22.000000      77.165000   25691.160000
# Class       0.000000       0.000000       1.000000

# %%
df.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
# class = 1 --> Fraud
#class = 0 --> Not Fraud

#Gives count of positive and negative labels
np.bincount(df['Class'])
# Out:
# array([284315,    492])

# %%
cols = df.columns.drop(['Time', 'Amount', 'Class'])

f, ax = plt.subplots(7, 4, figsize = (15, 28))

for i, c in zip(ax.flatten(), cols):
    sns.distplot(df[c][df['Class'] == 0], color = '#87bd75', ax = i)
    sns.distplot(df[c][df['Class'] == 1], color = '#b94646', ax = i)
f.tight_layout()

# %%
f, (ax1, ax2) = plt.subplots(2, 1, figsize = (12, 6))
plt.subplots_adjust(hspace = 0.5)
ax1.hist(df['Time'][df['Class'] == 0], bins = 50, color = 'crimson' ,alpha = 0.85)

ax1.set_xlabel('Time in secs')
ax1.set_title('Not Fraud')
ax1.set_ylabel('Number of Transactions')


ax2.hist(df["Time"][df['Class'] == 1], bins = 50, color = 'darkblue', alpha = 0.8)

ax2.set_xlabel('Time in secs')
ax2.set_ylabel("Number of Transactions")
ax2.set_title('Fraud')
plt.show()

# %%
f, (ax1, ax2) = plt.subplots(2, 1, figsize = (12, 6))
plt.subplots_adjust(hspace = 0.5)
ax1.hist(df['Amount'][df['Class'] == 0], bins = 50, color = 'crimson' ,alpha = 0.85)
ax1.set_xlabel('Amount')
ax1.set_title('Not Fraud')
ax1.set_ylabel('Number of Transactions')


ax2.hist(df["Amount"][df['Class'] == 1], bins = 50, color = 'darkblue', alpha = 0.8)
ax2.set_xlabel('Amount')
ax2.set_ylabel("Number of Transactions")
ax2.set_title('Fraud')
plt.show()

# %%
X = df.drop(['Time', 'Class'], axis = 1)
y = df['Class']

# %%
scaler = StandardScaler()
X['Amount'] = scaler.fit_transform(X[['Amount']])

# %%
X.head()
# Out:
#          V1        V2        V3        V4        V5        V6        V7  \
# 0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9       V10  ...       V20       V21       V22       V23  \
# 0  0.098698  0.363787  0.090794  ...  0.251412 -0.018307  0.277838 -0.110474
# 1  0.085102 -0.255425 -0.166974  ... -0.069083 -0.225775 -0.638672  0.101288
# 2  0.247676 -1.514654  0.207643  ...  0.524980  0.247998  0.771679  0.909412
# 3  0.377436 -1.387024 -0.054952  ... -0.208038 -0.108300  0.005274 -0.190321
# 4 -0.270533  0.817739  0.753074  ...  0.408542 -0.009431  0.798278 -0.137458
#
#         V24       V25       V26       V27       V28    Amount
# 0  0.066928  0.128539 -0.189115  0.133558 -0.021053  0.244964
# 1 -0.339846  0.167170  0.125895 -0.008983  0.014724 -0.342475
# 2 -0.689281 -0.327642 -0.139097 -0.055353 -0.059752  1.160686
# 3 -1.175575  0.647376 -0.221929  0.062723  0.061458  0.140534
# 4  0.141267 -0.206010  0.502292  0.219422  0.215153 -0.073403
#
# [5 rows x 29 columns]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, stratify = y)
X_train, X_valid, y_train, y_valid = train_test_split(X_train, y_train, test_size = 0.2, stratify = y_train)

# %%
def is_balanced_splitting(y):
    counts = np.bincount(y)
    return counts[1] / (sum(counts))

# %%
print('Percentage of FRAUD instances in Training Set : {}'.format(is_balanced_splitting(y_train) * 100))
print('Percentage of FRAUD instances in Testing Set : {}'.format(is_balanced_splitting(y_test) * 100))
print('Percentage of FRAUD instances in Validation set : {}'.format(is_balanced_splitting(y_valid) * 100))
# Out:
# Percentage of FRAUD instances in Training Set : 0.17281485220215498
# Percentage of FRAUD instances in Testing Set : 0.17204452090867595
# Percentage of FRAUD instances in Validation set : 0.1733634707805745

# %%
X_train.shape
# Out:
# (182276, 29)

# %% [markdown]
# ### Oversampling

# %%
def oversampling(X_train, y_train):
# Oversampling the imbalanced dataset
    oversample = SMOTE(random_state = 42, sampling_strategy = 0.4)
    X, y = oversample.fit_resample(X_train, y_train)
    # summarize the new class distribution
    counter = Counter(y)
    print(counter)
    return X, y
    # scatter plot of examples by class label

# %%
X_train, y_train = oversampling(X_train, y_train)
# Out:
# Counter({0: 181961, 1: 72784})

# %% [markdown]
# Now, it's fairly balanced data

# %%
sns.set(style="whitegrid")
labels = ['Not Fraud', 'Fraud']
sizes = y_train.value_counts()

colors = ["lightblue","red"]


plt.figure(figsize=(7,7))
plt.pie(sizes, labels=labels, colors=colors, autopct='%1.1f%%', startangle=90,)

plt.title('Frauds in the dataset')
plt.legend()
plt.show()

# %% [markdown]
# ### Adding Gaussian Noise

# %%
#Adding Gaussian Noise

def add_noise(X_train):
    mean = 0
    sigma = 0.1
    noise = np.random.normal(mean, sigma ,X_train.shape)
    X_train = X_train + noise
    return X_train

# %%
X_train_noised = add_noise(X_train)

# %%
y_train = np.array(y_train).reshape(-1, 1)
y_valid = np.array(y_valid).reshape(-1, 1)
y_test = np.array(y_test).reshape(-1, 1)

# %%
#from keras.utils import np_utils

#y_train = np_utils.to_categorical(y_train)
#y_test = np_utils.to_categorical(y_test)
#y_valid = np_utils.to_categorical(y_valid)

# Instead of:
# from keras.utils import np_utils
# y_train = np_utils.to_categorical(y_train)

# Use:
y_train = keras.utils.to_categorical(y_train)
y_test = keras.utils.to_categorical(y_test)
y_valid = keras.utils.to_categorical(y_valid)

# %% [markdown]
# ### Autoencoder Model

# %%
epochs = 25
batch_size = 128
input_shape = X_train.shape[1] #num of columns, 29
lr = 1e-7

#Autoencoder Model
input_layer = keras.layers.Input(shape=(input_shape, ))
encoder = keras.layers.Dense(128, activation = "relu", activity_regularizer = keras.regularizers.l1(lr),
                             kernel_initializer = 'lecun_normal')(input_layer)
encoder = keras.layers.Dense(64, activation = "relu")(encoder)
encoder = keras.layers.Dense(32, activation = 'relu')(encoder)
decoder = keras.layers.Dense(32, activation = 'relu')(encoder)
decoder = keras.layers.Dense(64, activation = 'relu')(decoder)
decoder = keras.layers.Dense(128, activation = 'relu')(decoder)
decoder = keras.layers.Dense(29, activation = 'relu')(decoder)
autoencoder = keras.Model(inputs=input_layer, outputs=decoder)

# %%
autoencoder.compile(metrics = ['accuracy'],
                    loss = 'mean_squared_error',
                    optimizer = 'adam')


history = autoencoder.fit(X_train_noised, X_train_noised,
                    epochs = epochs,
                    batch_size = batch_size,
                    shuffle = True,
                    validation_data = (X_valid, X_valid),
                    verbose=1).history
# Out:
# Epoch 1/25
# 1991/1991 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.5827 - loss: 7.5611 - val_accuracy: 0.8059 - val_loss: 0.6734
# Epoch 2/25
# 1991/1991 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.8087 - loss: 7.4520 - val_accuracy: 0.8029 - val_loss: 0.6941
# Epoch 3/25
# 1991/1991 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.8313 - loss: 7.4281 - val_accuracy: 0.8087 - val_loss: 0.6889
# Epoch 4/25
# 1991/1991 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.8400 - loss: 7.3941 - val_accuracy: 0.8025 - val_loss: 0.6878
# Epoch 5/25
# 1991/1991 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.8443 - loss: 7.4945 - val_accuracy: 0.8208 - val_loss: 0.6864
# Epoch 6/25
# 1991/1991 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.8490 - loss: 7.4849 - val_accuracy: 0.8259 - val_loss: 0.6841
# Epoch 7/25
# 1991/1991 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - accuracy: 0.8492 - loss: 7.4243 - val_accuracy: 0.8305 - val_loss: 0.6835
# Epoch 8/25
# 1991/1991 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.8544 - loss: 7.3938 - val_accuracy: 0.7951 - val_loss: 0.6888
# Epoch 9/25
# 1991/1991 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.8564 - loss: 7.4683 - val_accuracy: 0.8312 - val_loss: 0.6831
# Epoch 10/25
# 1991/1991 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.8597 - loss: 7.3911 - val_accuracy: 0.8261 - val_loss: 0.6833
# Epoch 11/25
# 1991/1991 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.8602 - loss: 7.4241 - val_accuracy: 0.8329 - val_loss: 0.6831
# Epoch 12/25
# 1991/1991 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.8509 - loss: 7.4356 - val_accuracy: 0.8359 - val_loss: 0.6791
# Epoch 13/25
# 1991/1991 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.8643 - loss: 7.4243 - val_accuracy: 0.8257 - val_loss: 0.6804
# Epoch 14/25
# 1991/1991 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.8583 - loss: 7.3825 - val_accuracy: 0.8372 - val_loss: 0.6791
# Epoch 15/25
# 1991/1991 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.8630 - loss: 7.5023 - val_accuracy: 0.8414 - val_loss: 0.6787
# Epoch 16/25
# 1991/1991 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.8666 - loss: 7.4242 - val_accuracy: 0.8385 - val_loss: 0.6789
# Epoch 17/25
# 1991/1991 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.8652 - loss: 7.3322 - val_accuracy: 0.8405 - val_loss: 0.6786
# Epoch 18/25
# 1991/1991 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.8669 - loss: 7.3738 - val_accuracy: 0.8339 - val_loss: 0.6791
# Epoch 19/25
# 1991/1991 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.8593 - loss: 7.4018 - val_accuracy: 0.8380 - val_loss: 0.6786
# Epoch 20/25
# 1991/1991 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.8635 - loss: 7.4537 - val_accuracy: 0.8422 - val_loss: 0.6786
# Epoch 21/25
# 1991/1991 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.8694 - loss: 7.4513 - val_accuracy: 0.8407 - val_loss: 0.6786
# Epoch 22/25
# 1991/1991 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.8654 - loss: 7.4025 - val_accuracy: 0.8433 - val_loss: 0.6784
# Epoch 23/25
# 1991/1991 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.8675 - loss: 7.3607 - val_accuracy: 0.8457 - val_loss: 0.6784
# Epoch 24/25
# 1991/1991 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.8630 - loss: 7.3945 - val_accuracy: 0.8429 - val_loss: 0.6785
# Epoch 25/25
# 1991/1991 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - accuracy: 0.8681 - loss: 7.3356 - val_accuracy: 0.8241 - val_loss: 0.6799

# %%
denoised_data = autoencoder.predict(X_train_noised)
# Out:
# 7961/7961 ━━━━━━━━━━━━━━━━━━━━ 12s 2ms/step

# %% [markdown]
# # Fraud Detector Model (Baseline)

# %%
epochs = 25
batch_size = 256
input_shape = X_train.shape[1] #num of columns, 29


input_layer = keras.layers.Input(shape = (input_shape, ))
layer_1 = keras.layers.Dense(128, activation = "relu",
                            kernel_initializer = 'lecun_normal')(input_layer)
layer_2 = keras.layers.Dense(64, activation = "relu", kernel_initializer = 'lecun_normal')(layer_1)
layer_3 = keras.layers.Dense(32, activation = 'relu', kernel_initializer = 'lecun_normal')(layer_2)
layer_4 = keras.layers.Dense(16, activation = 'relu', kernel_initializer = 'lecun_normal')(layer_3)
output_layer = keras.layers.Dense(2, activation = 'sigmoid')(layer_4)
fraud_dtr = keras.Model(inputs = input_layer, outputs = output_layer)

# %%
fraud_dtr.compile(metrics=['accuracy'],
                    loss='binary_crossentropy',
                    optimizer='sgd')

#callback = keras.callbacks.ModelCheckpoint('Fraud_Detector_model.h5',
#                                          save_best_only = True)
callback = keras.callbacks.ModelCheckpoint('Fraud_Detector_model.keras',
                                          save_best_only = True)

history = fraud_dtr.fit(denoised_data, y_train,
                    epochs = epochs,
                    batch_size  = 256,
                    validation_data = (X_valid, y_valid),
                    callbacks = [callback]).history
# Out:
# Epoch 1/25
# 996/996 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.8784 - loss: 0.4265 - val_accuracy: 0.9685 - val_loss: 0.1063
# Epoch 2/25
# 996/996 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9531 - loss: 0.1393 - val_accuracy: 0.9632 - val_loss: 0.1163
# Epoch 3/25
# 996/996 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9557 - loss: 0.1281 - val_accuracy: 0.9529 - val_loss: 0.1393
# Epoch 4/25
# 996/996 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.9576 - loss: 0.1192 - val_accuracy: 0.9501 - val_loss: 0.1460
# Epoch 5/25
# 996/996 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9595 - loss: 0.1110 - val_accuracy: 0.9440 - val_loss: 0.1604
# Epoch 6/25
# 996/996 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9630 - loss: 0.1027 - val_accuracy: 0.9398 - val_loss: 0.1718
# Epoch 7/25
# 996/996 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9655 - loss: 0.0951 - val_accuracy: 0.9284 - val_loss: 0.1994
# Epoch 8/25
# 996/996 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9679 - loss: 0.0883 - val_accuracy: 0.9255 - val_loss: 0.2097
# Epoch 9/25
# 996/996 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9705 - loss: 0.0807 - val_accuracy: 0.9276 - val_loss: 0.2102
# Epoch 10/25
# 996/996 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9727 - loss: 0.0744 - val_accuracy: 0.9195 - val_loss: 0.2426
# Epoch 11/25
# 996/996 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9752 - loss: 0.0676 - val_accuracy: 0.9123 - val_loss: 0.2789
# Epoch 12/25
# 996/996 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9788 - loss: 0.0603 - val_accuracy: 0.9197 - val_loss: 0.2567
# Epoch 13/25
# 996/996 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9802 - loss: 0.0556 - val_accuracy: 0.9066 - val_loss: 0.3204
# Epoch 14/25
# 996/996 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9822 - loss: 0.0515 - val_accuracy: 0.9275 - val_loss: 0.2497
# Epoch 15/25
# 996/996 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9841 - loss: 0.0463 - val_accuracy: 0.9117 - val_loss: 0.3194
# Epoch 16/25
# 996/996 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9854 - loss: 0.0425 - val_accuracy: 0.9235 - val_loss: 0.2885
# Epoch 17/25
# 996/996 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9869 - loss: 0.0397 - val_accuracy: 0.9284 - val_loss: 0.2721
# Epoch 18/25
# 996/996 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9874 - loss: 0.0393 - val_accuracy: 0.9357 - val_loss: 0.2540
# Epoch 19/25
# 996/996 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9884 - loss: 0.0344 - val_accuracy: 0.9323 - val_loss: 0.2719
# Epoch 20/25
# 996/996 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9894 - loss: 0.0320 - val_accuracy: 0.9336 - val_loss: 0.2735
# Epoch 21/25
# 996/996 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9898 - loss: 0.0314 - val_accuracy: 0.9380 - val_loss: 0.2589
# Epoch 22/25
# 996/996 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9905 - loss: 0.0292 - val_accuracy: 0.9443 - val_loss: 0.2346
# Epoch 23/25
# 996/996 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9911 - loss: 0.0273 - val_accuracy: 0.9387 - val_loss: 0.2634
# Epoch 24/25
# 996/996 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9914 - loss: 0.0268 - val_accuracy: 0.9397 - val_loss: 0.2618
# Epoch 25/25
# 996/996 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9921 - loss: 0.0248 - val_accuracy: 0.9439 - val_loss: 0.2494

# %% [markdown]
# ## Model Evaluation

# %%
#Load the best saved model

model = keras.models.load_model('Fraud_Detector_model.keras')

# %%
model.evaluate(X_test, y_test)
# Out:
# 1781/1781 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9674 - loss: 0.1109
# [0.11078187078237534, 0.9670833349227905]

# %%
preds = model.predict(X_test)
# Out:
# 1781/1781 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step

# %% [markdown]
# #### ROC-AUC Curve

# %%
#Plotting the ROC-AUC Curve

false_pos_rate, true_pos_rate, thresholds = roc_curve(y_test.argmax(axis = 1), preds[:,1])
roc_auc = auc(false_pos_rate, true_pos_rate,)

plt.plot(false_pos_rate, true_pos_rate, linewidth = 5, label = 'AUC = %0.3f'% roc_auc)
plt.plot([0,1],[0,1], linewidth = 5)

plt.xlim([-0.01, 1])
plt.ylim([0, 1.01])
plt.legend(loc='lower right')
plt.title('Receiver operating characteristic curve (ROC)')
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show()

# %% [markdown]
# #### Recall

# %%
print('Percentage of correctly predicting the Fraud Transactions : ', recall_score(y_test.argmax(axis = 1), preds.argmax(axis = 1)) * 100, '%')
# Out:
# Percentage of correctly predicting the Fraud Transactions :  78.57142857142857 %

# %% [markdown]
# #### PR-AUC Curve

# %%
from sklearn.metrics import precision_recall_curve
from sklearn.metrics import auc

precision, recall, thresholds = precision_recall_curve(y_test.argmax(axis = 1), preds[:,1])
pr_auc = auc(recall, precision)

plt.plot(recall, precision, linewidth = 5, label = 'AUC = %0.3f'% pr_auc)

plt.xlim([-0.01, 1.01])
plt.ylim([0, 1.01])
plt.legend(loc='lower right')
plt.title('Precision Recall Curve')
plt.ylabel('Precision')
plt.xlabel('Recall')
plt.show()

# %% [markdown]
# # Measuring the Effect of Denoising Autoencoder

# %% [markdown]
# In this section we will train the model on X_train, instead of denoised_data, and see the difference in perforemance between the models

# %%
epochs = 25
batch_size = 128
input_shape = X_train.shape[1] #num of columns, 29
lr = 1e-7

#Autoencoder Model
input_layer = keras.layers.Input(shape=(input_shape, ))
encoder = keras.layers.Dense(128, activation = "relu", activity_regularizer = keras.regularizers.l1(lr),
                             kernel_initializer = 'lecun_normal')(input_layer)
encoder = keras.layers.Dense(64, activation = "relu")(encoder)
encoder = keras.layers.Dense(32, activation = 'relu')(encoder)
decoder = keras.layers.Dense(32, activation = 'relu')(encoder)
decoder = keras.layers.Dense(64, activation = 'relu')(decoder)
decoder = keras.layers.Dense(128, activation = 'relu')(decoder)
decoder = keras.layers.Dense(29, activation = 'relu')(decoder)
autoencoder = keras.Model(inputs=input_layer, outputs=decoder)

# %%
fraud_dtr.compile(metrics=['accuracy'],
                    loss='binary_crossentropy',
                    optimizer='sgd')

#callback = keras.callbacks.ModelCheckpoint('Fraud_Detector_model.h5',
#                                          save_best_only = True)
callback = keras.callbacks.ModelCheckpoint('Fraud_Detector_model.keras',
                                          save_best_only = True)

history = fraud_dtr.fit(X_train_noised, y_train,
                    epochs = epochs,
                    batch_size  = 256,
                    validation_data = (X_valid, y_valid),
                    callbacks = [callback]).history
# Out:
# Epoch 1/25
# 996/996 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.9696 - loss: 0.1284 - val_accuracy: 0.9938 - val_loss: 0.0180
# Epoch 2/25
# 996/996 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9881 - loss: 0.0334 - val_accuracy: 0.9928 - val_loss: 0.0194
# Epoch 3/25
# 996/996 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9924 - loss: 0.0235 - val_accuracy: 0.9945 - val_loss: 0.0166
# Epoch 4/25
# 996/996 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9944 - loss: 0.0184 - val_accuracy: 0.9939 - val_loss: 0.0187
# Epoch 5/25
# 996/996 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9956 - loss: 0.0155 - val_accuracy: 0.9952 - val_loss: 0.0151
# Epoch 6/25
# 996/996 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9964 - loss: 0.0133 - val_accuracy: 0.9937 - val_loss: 0.0200
# Epoch 7/25
# 996/996 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9968 - loss: 0.0119 - val_accuracy: 0.9964 - val_loss: 0.0124
# Epoch 8/25
# 996/996 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9972 - loss: 0.0114 - val_accuracy: 0.9964 - val_loss: 0.0124
# Epoch 9/25
# 996/996 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9973 - loss: 0.0101 - val_accuracy: 0.9957 - val_loss: 0.0139
# Epoch 10/25
# 996/996 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9980 - loss: 0.0084 - val_accuracy: 0.9970 - val_loss: 0.0113
# Epoch 11/25
# 996/996 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9979 - loss: 0.0086 - val_accuracy: 0.9964 - val_loss: 0.0123
# Epoch 12/25
# 996/996 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9981 - loss: 0.0076 - val_accuracy: 0.9968 - val_loss: 0.0119
# Epoch 13/25
# 996/996 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9982 - loss: 0.0075 - val_accuracy: 0.9975 - val_loss: 0.0103
# Epoch 14/25
# 996/996 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9984 - loss: 0.0064 - val_accuracy: 0.9983 - val_loss: 0.0087
# Epoch 15/25
# 996/996 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9985 - loss: 0.0066 - val_accuracy: 0.9965 - val_loss: 0.0128
# Epoch 16/25
# 996/996 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9985 - loss: 0.0067 - val_accuracy: 0.9977 - val_loss: 0.0100
# Epoch 17/25
# 996/996 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9984 - loss: 0.0065 - val_accuracy: 0.9973 - val_loss: 0.0112
# Epoch 18/25
# 996/996 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9987 - loss: 0.0055 - val_accuracy: 0.9977 - val_loss: 0.0097
# Epoch 19/25
# 996/996 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9987 - loss: 0.0054 - val_accuracy: 0.9971 - val_loss: 0.0115
# Epoch 20/25
# 996/996 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9989 - loss: 0.0047 - val_accuracy: 0.9978 - val_loss: 0.0098
# Epoch 21/25
# 996/996 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9988 - loss: 0.0050 - val_accuracy: 0.9977 - val_loss: 0.0104
# Epoch 22/25
# 996/996 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9988 - loss: 0.0050 - val_accuracy: 0.9977 - val_loss: 0.0102
# Epoch 23/25
# 996/996 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9989 - loss: 0.0046 - val_accuracy: 0.9975 - val_loss: 0.0103
# Epoch 24/25
# 996/996 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.9989 - loss: 0.0047 - val_accuracy: 0.9976 - val_loss: 0.0102
# Epoch 25/25
# 996/996 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9989 - loss: 0.0047 - val_accuracy: 0.9974 - val_loss: 0.0110

# %%
#Load the best saved model

model = keras.models.load_model('Fraud_Detector_model.keras')

# %%
model.evaluate(X_test, y_test)
# Out:
# 1781/1781 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9984 - loss: 0.0081
# [0.009459767490625381, 0.9983322024345398]

# %%
preds = model.predict(X_test)
# Out:
# 1781/1781 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step

# %% [markdown]
# ## Model Evaluation

# %% [markdown]
# #### ROC-AUC Curve

# %%
#Plotting the ROC-AUC Curve

false_pos_rate, true_pos_rate, thresholds = roc_curve(y_test.argmax(axis = 1), preds[:,1])
roc_auc = auc(false_pos_rate, true_pos_rate,)

plt.plot(false_pos_rate, true_pos_rate, linewidth = 5, label = 'AUC = %0.3f'% roc_auc)
plt.plot([0,1],[0,1], linewidth = 5)

plt.xlim([-0.01, 1])
plt.ylim([0, 1.01])
plt.legend(loc='lower right')
plt.title('Receiver operating characteristic curve (ROC)')
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show()

# %% [markdown]
# #### Recall

# %%
print('Percentage of correctly predicting the Fraud Transactions : ', recall_score(y_test.argmax(axis = 1), preds.argmax(axis = 1)) * 100, '%')
# Out:
# Percentage of correctly predicting the Fraud Transactions :  85.71428571428571 %

# %% [markdown]
# #### PR-AUC Curve

# %%
precision, recall, thresholds = precision_recall_curve(y_test.argmax(axis = 1), preds[:,1])
pr_auc = auc(recall, precision)

plt.plot(recall, precision, linewidth = 5, label = 'AUC = %0.3f'% pr_auc)

plt.xlim([-0.01, 1.01])
plt.ylim([0, 1.01])
plt.legend(loc='lower right')
plt.title('Precision Recall Curve')
plt.ylabel('Precision')
plt.xlabel('Recall')
plt.show()

# %% [markdown]
# # Applying PR AUC instead of Accuracy

# %% [markdown]
# The PR AUC was calculated with code taken from here:
#
# https://www.kaggle.com/code/nyk510/using-pr-auc-metrics-in-keras

# %%
from tensorflow.keras.metrics import AUC
pr_metric = AUC(curve='PR', num_thresholds=1000) # The higher the threshold value, the more accurate it is calculated.

import tensorflow as tf
from sklearn.metrics import average_precision_score

def sk_pr_auc(y_true, y_pred):
    return tf.py_function(average_precision_score, (y_true, y_pred), tf.float64)

model.compile(loss='binary_crossentropy', optimizer='adam',
              metrics=[
                  pr_metric,
                  sk_pr_auc
              ])

# %%
epochs = 25
batch_size = 256
input_shape = X_train.shape[1] #num of columns, 29


input_layer = keras.layers.Input(shape = (input_shape, ))
layer_1 = keras.layers.Dense(128, activation = "relu",
                            kernel_initializer = 'lecun_normal')(input_layer)
layer_2 = keras.layers.Dense(64, activation = "relu", kernel_initializer = 'lecun_normal')(layer_1)
layer_3 = keras.layers.Dense(32, activation = 'relu', kernel_initializer = 'lecun_normal')(layer_2)
layer_4 = keras.layers.Dense(16, activation = 'relu', kernel_initializer = 'lecun_normal')(layer_3)
output_layer = keras.layers.Dense(2, activation = 'sigmoid')(layer_4)
fraud_dtr = keras.Model(inputs = input_layer, outputs = output_layer)

# %%
fraud_dtr.compile(metrics=[pr_metric],
                    loss='binary_crossentropy',
                    optimizer='sgd')

#callback = keras.callbacks.ModelCheckpoint('Fraud_Detector_model.h5',
#                                          save_best_only = True)
callback = keras.callbacks.ModelCheckpoint('Fraud_Detector_model.keras',
                                          save_best_only = True)

history = fraud_dtr.fit(X_train_noised, y_train,
                    epochs = epochs,
                    batch_size  = 256,
                    validation_data = (X_valid, y_valid),
                    callbacks = [callback]).history
# Out:
# Epoch 1/25
# 996/996 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - auc_1: 0.9309 - loss: 0.3516 - val_auc_1: 0.9986 - val_loss: 0.0547
# Epoch 2/25
# 996/996 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - auc_1: 0.9931 - loss: 0.1074 - val_auc_1: 0.9989 - val_loss: 0.0421
# Epoch 3/25
# 996/996 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - auc_1: 0.9955 - loss: 0.0861 - val_auc_1: 0.9990 - val_loss: 0.0385
# Epoch 4/25
# 996/996 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - auc_1: 0.9967 - loss: 0.0743 - val_auc_1: 0.9992 - val_loss: 0.0328
# Epoch 5/25
# 996/996 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - auc_1: 0.9978 - loss: 0.0612 - val_auc_1: 0.9992 - val_loss: 0.0321
# Epoch 6/25
# 996/996 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - auc_1: 0.9984 - loss: 0.0521 - val_auc_1: 0.9994 - val_loss: 0.0273
# Epoch 7/25
# 996/996 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - auc_1: 0.9989 - loss: 0.0433 - val_auc_1: 0.9994 - val_loss: 0.0239
# Epoch 8/25
# 996/996 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - auc_1: 0.9992 - loss: 0.0363 - val_auc_1: 0.9995 - val_loss: 0.0231
# Epoch 9/25
# 996/996 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - auc_1: 0.9994 - loss: 0.0312 - val_auc_1: 0.9995 - val_loss: 0.0212
# Epoch 10/25
# 996/996 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - auc_1: 0.9995 - loss: 0.0265 - val_auc_1: 0.9997 - val_loss: 0.0149
# Epoch 11/25
# 996/996 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - auc_1: 0.9996 - loss: 0.0243 - val_auc_1: 0.9997 - val_loss: 0.0137
# Epoch 12/25
# 996/996 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - auc_1: 0.9996 - loss: 0.0210 - val_auc_1: 0.9997 - val_loss: 0.0139
# Epoch 13/25
# 996/996 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - auc_1: 0.9997 - loss: 0.0192 - val_auc_1: 0.9996 - val_loss: 0.0156
# Epoch 14/25
# 996/996 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - auc_1: 0.9997 - loss: 0.0167 - val_auc_1: 0.9997 - val_loss: 0.0134
# Epoch 15/25
# 996/996 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - auc_1: 0.9997 - loss: 0.0162 - val_auc_1: 0.9997 - val_loss: 0.0139
# Epoch 16/25
# 996/996 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - auc_1: 0.9997 - loss: 0.0152 - val_auc_1: 0.9997 - val_loss: 0.0128
# Epoch 17/25
# 996/996 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - auc_1: 0.9997 - loss: 0.0137 - val_auc_1: 0.9997 - val_loss: 0.0116
# Epoch 18/25
# 996/996 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - auc_1: 0.9998 - loss: 0.0130 - val_auc_1: 0.9997 - val_loss: 0.0141
# Epoch 19/25
# 996/996 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - auc_1: 0.9997 - loss: 0.0126 - val_auc_1: 0.9997 - val_loss: 0.0125
# Epoch 20/25
# 996/996 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - auc_1: 0.9997 - loss: 0.0115 - val_auc_1: 0.9997 - val_loss: 0.0116
# Epoch 21/25
# 996/996 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - auc_1: 0.9998 - loss: 0.0105 - val_auc_1: 0.9997 - val_loss: 0.0106
# Epoch 22/25
# 996/996 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - auc_1: 0.9998 - loss: 0.0100 - val_auc_1: 0.9997 - val_loss: 0.0107
# Epoch 23/25
# 996/996 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - auc_1: 0.9998 - loss: 0.0096 - val_auc_1: 0.9997 - val_loss: 0.0093
# Epoch 24/25
# 996/996 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - auc_1: 0.9998 - loss: 0.0095 - val_auc_1: 0.9997 - val_loss: 0.0106
# Epoch 25/25
# 996/996 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - auc_1: 0.9999 - loss: 0.0083 - val_auc_1: 0.9996 - val_loss: 0.0094

# %% [markdown]
# ## Model Evaluation

# %%
#Load the best saved model

model = keras.models.load_model('Fraud_Detector_model.keras')

# %%
model.evaluate(X_test, y_test)
# Out:
# 1781/1781 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - auc_1: 0.9996 - loss: 0.0092
# [0.00990003440529108, 0.9996614456176758]

# %%
preds = model.predict(X_test)
# Out:
# 1781/1781 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step

# %% [markdown]
# #### ROC-AUC Curve

# %%
#Plotting the ROC-AUC Curve

false_pos_rate, true_pos_rate, thresholds = roc_curve(y_test.argmax(axis = 1), preds[:,1])
roc_auc = auc(false_pos_rate, true_pos_rate,)

plt.plot(false_pos_rate, true_pos_rate, linewidth = 5, label = 'AUC = %0.3f'% roc_auc)
plt.plot([0,1],[0,1], linewidth = 5)

plt.xlim([-0.01, 1])
plt.ylim([0, 1.01])
plt.legend(loc='lower right')
plt.title('Receiver operating characteristic curve (ROC)')
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show()

# %% [markdown]
# #### Recall

# %%
print('Percentage of correctly predicting the Fraud Transactions : ', recall_score(y_test.argmax(axis = 1), preds.argmax(axis = 1)) * 100, '%')
# Out:
# Percentage of correctly predicting the Fraud Transactions :  88.77551020408163 %

# %% [markdown]
# #### PR-AUC Curve

# %%
precision, recall, thresholds = precision_recall_curve(y_test.argmax(axis = 1), preds[:,1])
pr_auc = auc(recall, precision)

plt.plot(recall, precision, linewidth = 5, label = 'AUC = %0.3f'% pr_auc)

plt.xlim([-0.01, 1.01])
plt.ylim([0, 1.01])
plt.legend(loc='lower right')
plt.title('Precision Recall Curve')
plt.ylabel('Precision')
plt.xlabel('Recall')
plt.show()

# %% [markdown]
# # Improved Fraud detector

# %%
from tensorflow.keras import regularizers

input_layer = keras.layers.Input(shape=(input_shape,))
layer_1 = keras.layers.Dense(128, activation="relu",
                             kernel_initializer='he_normal')(input_layer)
drop_1 = keras.layers.Dropout(0.2)(layer_1)

layer_2 = keras.layers.Dense(64, activation="relu",
                             kernel_initializer='he_normal')(drop_1)
drop_2 = keras.layers.Dropout(0.2)(layer_2)

layer_3 = keras.layers.Dense(32, activation='relu',
                             kernel_initializer='he_normal')(drop_2)
layer_4 = keras.layers.Dense(16, activation='relu',
                             kernel_initializer='he_normal')(layer_3)
output_layer = keras.layers.Dense(2, activation='sigmoid')(layer_4)

fraud_dtr = keras.Model(inputs=input_layer, outputs=output_layer)

# %%
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau

early_stop = EarlyStopping(monitor='val_loss', patience=3, restore_best_weights=True)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=2)

fraud_dtr.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
history = fraud_dtr.fit(X_train_noised, y_train, epochs=25, batch_size=256,
              validation_split=0.2, callbacks=[early_stop, reduce_lr],validation_data = (X_valid, y_valid)).history
# Out:
# Epoch 1/25
# 996/996 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.9242 - loss: 0.1785 - val_accuracy: 0.9946 - val_loss: 0.0172 - learning_rate: 0.0010
# Epoch 2/25
# 996/996 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9886 - loss: 0.0319 - val_accuracy: 0.9966 - val_loss: 0.0111 - learning_rate: 0.0010
# Epoch 3/25
# 996/996 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9944 - loss: 0.0167 - val_accuracy: 0.9970 - val_loss: 0.0111 - learning_rate: 0.0010
# Epoch 4/25
# 996/996 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9964 - loss: 0.0122 - val_accuracy: 0.9974 - val_loss: 0.0109 - learning_rate: 0.0010
# Epoch 5/25
# 996/996 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.9969 - loss: 0.0106 - val_accuracy: 0.9978 - val_loss: 0.0103 - learning_rate: 0.0010
# Epoch 6/25
# 996/996 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9975 - loss: 0.0087 - val_accuracy: 0.9981 - val_loss: 0.0096 - learning_rate: 0.0010
# Epoch 7/25
# 996/996 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9977 - loss: 0.0083 - val_accuracy: 0.9984 - val_loss: 0.0095 - learning_rate: 0.0010
# Epoch 8/25
# 996/996 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.9982 - loss: 0.0066 - val_accuracy: 0.9986 - val_loss: 0.0094 - learning_rate: 0.0010
# Epoch 9/25
# 996/996 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9984 - loss: 0.0062 - val_accuracy: 0.9985 - val_loss: 0.0084 - learning_rate: 0.0010
# Epoch 10/25
# 996/996 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9982 - loss: 0.0063 - val_accuracy: 0.9983 - val_loss: 0.0102 - learning_rate: 0.0010
# Epoch 11/25
# 996/996 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9985 - loss: 0.0057 - val_accuracy: 0.9984 - val_loss: 0.0106 - learning_rate: 0.0010
# Epoch 12/25
# 996/996 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9988 - loss: 0.0048 - val_accuracy: 0.9986 - val_loss: 0.0098 - learning_rate: 5.0000e-04

# %%
fraud_dtr.compile(metrics=['accuracy'],
                    loss='binary_crossentropy',
                    optimizer='sgd')

#callback = keras.callbacks.ModelCheckpoint('Fraud_Detector_model.h5',
#                                          save_best_only = True)
callback = keras.callbacks.ModelCheckpoint('Fraud_Detector_model.keras',
                                          save_best_only = True)

history = fraud_dtr.fit(X_train_noised, y_train,
                    epochs = epochs,
                    batch_size  = 256,
                    validation_data = (X_valid, y_valid),
                    callbacks = [callback]).history
# Out:
# Epoch 1/25
# 996/996 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - accuracy: 0.9984 - loss: 0.0059 - val_accuracy: 0.9984 - val_loss: 0.0089
# Epoch 2/25
# 996/996 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.9985 - loss: 0.0057 - val_accuracy: 0.9984 - val_loss: 0.0089
# Epoch 3/25
# 996/996 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9986 - loss: 0.0054 - val_accuracy: 0.9985 - val_loss: 0.0089
# Epoch 4/25
# 996/996 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9987 - loss: 0.0050 - val_accuracy: 0.9985 - val_loss: 0.0089
# Epoch 5/25
# 996/996 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.9987 - loss: 0.0051 - val_accuracy: 0.9985 - val_loss: 0.0089
# Epoch 6/25
# 996/996 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9986 - loss: 0.0047 - val_accuracy: 0.9985 - val_loss: 0.0089
# Epoch 7/25
# 996/996 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9987 - loss: 0.0048 - val_accuracy: 0.9985 - val_loss: 0.0090
# Epoch 8/25
# 996/996 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9987 - loss: 0.0052 - val_accuracy: 0.9985 - val_loss: 0.0090
# Epoch 9/25
# 996/996 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9989 - loss: 0.0046 - val_accuracy: 0.9985 - val_loss: 0.0090
# Epoch 10/25
# 996/996 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9987 - loss: 0.0047 - val_accuracy: 0.9985 - val_loss: 0.0091
# Epoch 11/25
# 996/996 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9988 - loss: 0.0048 - val_accuracy: 0.9985 - val_loss: 0.0091
# Epoch 12/25
# 996/996 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9988 - loss: 0.0046 - val_accuracy: 0.9985 - val_loss: 0.0091
# Epoch 13/25
# 996/996 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9988 - loss: 0.0045 - val_accuracy: 0.9985 - val_loss: 0.0091
# Epoch 14/25
# 996/996 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9988 - loss: 0.0045 - val_accuracy: 0.9986 - val_loss: 0.0091
# Epoch 15/25
# 996/996 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9987 - loss: 0.0046 - val_accuracy: 0.9986 - val_loss: 0.0091
# Epoch 16/25
# 996/996 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9989 - loss: 0.0042 - val_accuracy: 0.9986 - val_loss: 0.0091
# Epoch 17/25
# 996/996 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9987 - loss: 0.0050 - val_accuracy: 0.9986 - val_loss: 0.0093
# Epoch 18/25
# 996/996 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9989 - loss: 0.0042 - val_accuracy: 0.9986 - val_loss: 0.0093
# Epoch 19/25
# 996/996 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9988 - loss: 0.0048 - val_accuracy: 0.9986 - val_loss: 0.0093
# Epoch 20/25
# 996/996 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9990 - loss: 0.0041 - val_accuracy: 0.9987 - val_loss: 0.0093
# Epoch 21/25
# 996/996 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9989 - loss: 0.0044 - val_accuracy: 0.9986 - val_loss: 0.0093
# Epoch 22/25
# 996/996 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9989 - loss: 0.0044 - val_accuracy: 0.9986 - val_loss: 0.0093
# Epoch 23/25
# 996/996 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9989 - loss: 0.0042 - val_accuracy: 0.9986 - val_loss: 0.0094
# Epoch 24/25
# 996/996 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9989 - loss: 0.0041 - val_accuracy: 0.9987 - val_loss: 0.0093
# Epoch 25/25
# 996/996 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9989 - loss: 0.0048 - val_accuracy: 0.9987 - val_loss: 0.0093

# %%
#Load the best saved model

model = keras.models.load_model('Fraud_Detector_model.keras')

# %%
model.evaluate(X_test, y_test)
# Out:
# 1781/1781 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9987 - loss: 0.0109
# [0.01205309759825468, 0.9985077977180481]

# %%
preds = model.predict(X_test)
# Out:
# 1781/1781 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step

# %% [markdown]
# ## Model Evaluation

# %% [markdown]
# #### ROC-AUC Curve

# %%
#Plotting the ROC-AUC Curve

false_pos_rate, true_pos_rate, thresholds = roc_curve(y_test.argmax(axis = 1), preds[:,1])
roc_auc = auc(false_pos_rate, true_pos_rate,)

plt.plot(false_pos_rate, true_pos_rate, linewidth = 5, label = 'AUC = %0.3f'% roc_auc)
plt.plot([0,1],[0,1], linewidth = 5)

plt.xlim([-0.01, 1])
plt.ylim([0, 1.01])
plt.legend(loc='lower right')
plt.title('Receiver operating characteristic curve (ROC)')
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show()

# %% [markdown]
# #### Recall

# %%
print('Percentage of correctly predicting the Fraud Transactions : ', recall_score(y_test.argmax(axis = 1), preds.argmax(axis = 1)) * 100, '%')
# Out:
# Percentage of correctly predicting the Fraud Transactions :  86.73469387755102 %

# %% [markdown]
# #### PR-AUC Curve

# %%
precision, recall, thresholds = precision_recall_curve(y_test.argmax(axis = 1), preds[:,1])
pr_auc = auc(recall, precision)

plt.plot(recall, precision, linewidth = 5, label = 'AUC = %0.3f'% pr_auc)

plt.xlim([-0.01, 1.01])
plt.ylim([0, 1.01])
plt.legend(loc='lower right')
plt.title('Precision Recall Curve')
plt.ylabel('Precision')
plt.xlabel('Recall')
plt.show()
