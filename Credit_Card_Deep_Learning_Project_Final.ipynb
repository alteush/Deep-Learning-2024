# %% [markdown]
# <a href="https://colab.research.google.com/github/alteush/Deep-Learning-2024/blob/main/Credit_Card_Deep_Learning_Project_Final.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import roc_curve, auc, recall_score
import imblearn
from collections import Counter
from imblearn.over_sampling import SMOTE
from sklearn.model_selection import train_test_split

import tensorflow as tf
from tensorflow import keras

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
from google.colab import drive
drive.mount("/content/drive/")
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
import sys
your_drive_path_to_src_file = "/content/drive/MyDrive/Statistics Masters/Adv. computational learning and data analysis/Project/Data/"
sys.path.append(your_drive_path_to_src_file)

# %%
# original path
# df = pd.read_csv("CSV/creditcard.csv")
df = pd.read_csv("/content/drive/MyDrive/Statistics Masters/Adv. computational learning and data analysis/Project/Data/creditcard.csv")

# %%
df.shape
# Out:
# (284807, 31)
# (284807, 31)

# %%
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
#         V26       V27       V28  Amount  Class
# 0 -0.189115  0.133558 -0.021053  149.62      0
# 1  0.125895 -0.008983  0.014724    2.69      0
# 2 -0.139097 -0.055353 -0.059752  378.66      0
# 3 -0.221929  0.062723  0.061458  123.50      0
# 4  0.502292  0.219422  0.215153   69.99      0
#
# [5 rows x 31 columns]
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
#         V26       V27       V28  Amount  Class
# 0 -0.189115  0.133558 -0.021053  149.62      0
# 1  0.125895 -0.008983  0.014724    2.69      0
# 2 -0.139097 -0.055353 -0.059752  378.66      0
# 3 -0.221929  0.062723  0.061458  123.50      0
# 4  0.502292  0.219422  0.215153   69.99      0
#
# [5 rows x 31 columns]

# %%
df.describe().T
# Out:
#            count          mean           std         min           25%  \
# Time    284807.0  9.481386e+04  47488.145955    0.000000  54201.500000
# V1      284807.0  1.168375e-15      1.958696  -56.407510     -0.920373
# V2      284807.0  3.416908e-16      1.651309  -72.715728     -0.598550
# V3      284807.0 -1.379537e-15      1.516255  -48.325589     -0.890365
# V4      284807.0  2.074095e-15      1.415869   -5.683171     -0.848640
# V5      284807.0  9.604066e-16      1.380247 -113.743307     -0.691597
# V6      284807.0  1.487313e-15      1.332271  -26.160506     -0.768296
# V7      284807.0 -5.556467e-16      1.237094  -43.557242     -0.554076
# V8      284807.0  1.213481e-16      1.194353  -73.216718     -0.208630
# V9      284807.0 -2.406331e-15      1.098632  -13.434066     -0.643098
# V10     284807.0  2.239053e-15      1.088850  -24.588262     -0.535426
# V11     284807.0  1.673327e-15      1.020713   -4.797473     -0.762494
# V12     284807.0 -1.247012e-15      0.999201  -18.683715     -0.405571
# V13     284807.0  8.190001e-16      0.995274   -5.791881     -0.648539
# V14     284807.0  1.207294e-15      0.958596  -19.214325     -0.425574
# V15     284807.0  4.887456e-15      0.915316   -4.498945     -0.582884
# V16     284807.0  1.437716e-15      0.876253  -14.129855     -0.468037
# V17     284807.0 -3.772171e-16      0.849337  -25.162799     -0.483748
# V18     284807.0  9.564149e-16      0.838176   -9.498746     -0.498850
# V19     284807.0  1.039917e-15      0.814041   -7.213527     -0.456299
# V20     284807.0  6.406204e-16      0.770925  -54.497720     -0.211721
# V21     284807.0  1.654067e-16      0.734524  -34.830382     -0.228395
# V22     284807.0 -3.568593e-16      0.725702  -10.933144     -0.542350
# V23     284807.0  2.578648e-16      0.624460  -44.807735     -0.161846
# V24     284807.0  4.473266e-15      0.605647   -2.836627     -0.354586
# V25     284807.0  5.340915e-16      0.521278  -10.295397     -0.317145
# V26     284807.0  1.683437e-15      0.482227   -2.604551     -0.326984
# V27     284807.0 -3.660091e-16      0.403632  -22.565679     -0.070840
# V28     284807.0 -1.227390e-16      0.330083  -15.430084     -0.052960
# Amount  284807.0  8.834962e+01    250.120109    0.000000      5.600000
# Class   284807.0  1.727486e-03      0.041527    0.000000      0.000000
#
#                  50%            75%            max
# Time    84692.000000  139320.500000  172792.000000
# V1          0.018109       1.315642       2.454930
# V2          0.065486       0.803724      22.057729
# V3          0.179846       1.027196       9.382558
# V4         -0.019847       0.743341      16.875344
# V5         -0.054336       0.611926      34.801666
# V6         -0.274187       0.398565      73.301626
# V7          0.040103       0.570436     120.589494
# V8          0.022358       0.327346      20.007208
# V9         -0.051429       0.597139      15.594995
# V10        -0.092917       0.453923      23.745136
# V11        -0.032757       0.739593      12.018913
# V12         0.140033       0.618238       7.848392
# V13        -0.013568       0.662505       7.126883
# V14         0.050601       0.493150      10.526766
# V15         0.048072       0.648821       8.877742
# V16         0.066413       0.523296      17.315112
# V17        -0.065676       0.399675       9.253526
# V18        -0.003636       0.500807       5.041069
# V19         0.003735       0.458949       5.591971
# V20        -0.062481       0.133041      39.420904
# V21        -0.029450       0.186377      27.202839
# V22         0.006782       0.528554      10.503090
# V23        -0.011193       0.147642      22.528412
# V24         0.040976       0.439527       4.584549
# V25         0.016594       0.350716       7.519589
# V26        -0.052139       0.240952       3.517346
# V27         0.001342       0.091045      31.612198
# V28         0.011244       0.078280      33.847808
# Amount     22.000000      77.165000   25691.160000
# Class       0.000000       0.000000       1.000000
#            count          mean           std         min           25%  \
# Time    284807.0  9.481386e+04  47488.145955    0.000000  54201.500000
# V1      284807.0  1.168375e-15      1.958696  -56.407510     -0.920373
# V2      284807.0  3.416908e-16      1.651309  -72.715728     -0.598550
# V3      284807.0 -1.379537e-15      1.516255  -48.325589     -0.890365
# V4      284807.0  2.074095e-15      1.415869   -5.683171     -0.848640
# V5      284807.0  9.604066e-16      1.380247 -113.743307     -0.691597
# V6      284807.0  1.487313e-15      1.332271  -26.160506     -0.768296
# V7      284807.0 -5.556467e-16      1.237094  -43.557242     -0.554076
# V8      284807.0  1.213481e-16      1.194353  -73.216718     -0.208630
# V9      284807.0 -2.406331e-15      1.098632  -13.434066     -0.643098
# V10     284807.0  2.239053e-15      1.088850  -24.588262     -0.535426
# V11     284807.0  1.673327e-15      1.020713   -4.797473     -0.762494
# V12     284807.0 -1.247012e-15      0.999201  -18.683715     -0.405571
# V13     284807.0  8.190001e-16      0.995274   -5.791881     -0.648539
# V14     284807.0  1.207294e-15      0.958596  -19.214325     -0.425574
# V15     284807.0  4.887456e-15      0.915316   -4.498945     -0.582884
# V16     284807.0  1.437716e-15      0.876253  -14.129855     -0.468037
# V17     284807.0 -3.772171e-16      0.849337  -25.162799     -0.483748
# V18     284807.0  9.564149e-16      0.838176   -9.498746     -0.498850
# V19     284807.0  1.039917e-15      0.814041   -7.213527     -0.456299
# V20     284807.0  6.406204e-16      0.770925  -54.497720     -0.211721
# V21     284807.0  1.654067e-16      0.734524  -34.830382     -0.228395
# V22     284807.0 -3.568593e-16      0.725702  -10.933144     -0.542350
# V23     284807.0  2.578648e-16      0.624460  -44.807735     -0.161846
# V24     284807.0  4.473266e-15      0.605647   -2.836627     -0.354586
# V25     284807.0  5.340915e-16      0.521278  -10.295397     -0.317145
# V26     284807.0  1.683437e-15      0.482227   -2.604551     -0.326984
# V27     284807.0 -3.660091e-16      0.403632  -22.565679     -0.070840
# V28     284807.0 -1.227390e-16      0.330083  -15.430084     -0.052960
# Amount  284807.0  8.834962e+01    250.120109    0.000000      5.600000
# Class   284807.0  1.727486e-03      0.041527    0.000000      0.000000
#
#                  50%            75%            max
# Time    84692.000000  139320.500000  172792.000000
# V1          0.018109       1.315642       2.454930
# V2          0.065486       0.803724      22.057729
# V3          0.179846       1.027196       9.382558
# V4         -0.019847       0.743341      16.875344
# V5         -0.054336       0.611926      34.801666
# V6         -0.274187       0.398565      73.301626
# V7          0.040103       0.570436     120.589494
# V8          0.022358       0.327346      20.007208
# V9         -0.051429       0.597139      15.594995
# V10        -0.092917       0.453923      23.745136
# V11        -0.032757       0.739593      12.018913
# V12         0.140033       0.618238       7.848392
# V13        -0.013568       0.662505       7.126883
# V14         0.050601       0.493150      10.526766
# V15         0.048072       0.648821       8.877742
# V16         0.066413       0.523296      17.315112
# V17        -0.065676       0.399675       9.253526
# V18        -0.003636       0.500807       5.041069
# V19         0.003735       0.458949       5.591971
# V20        -0.062481       0.133041      39.420904
# V21        -0.029450       0.186377      27.202839
# V22         0.006782       0.528554      10.503090
# V23        -0.011193       0.147642      22.528412
# V24         0.040976       0.439527       4.584549
# V25         0.016594       0.350716       7.519589
# V26        -0.052139       0.240952       3.517346
# V27         0.001342       0.091045      31.612198
# V28         0.011244       0.078280      33.847808
# Amount     22.000000      77.165000   25691.160000
# Class       0.000000       0.000000       1.000000

# %%
df.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
# class = 1 --> Fraud
#class = 0 --> Not Fraud

#Gives count of positive and negative labels
np.bincount(df['Class'])
# Out:
# array([284315,    492])
# array([284315,    492])

# %%
cols = df.columns.drop(['Time', 'Amount', 'Class'])

f, ax = plt.subplots(7, 4, figsize = (15, 28))

for i, c in zip(ax.flatten(), cols):
    sns.distplot(df[c][df['Class'] == 0], color = '#87bd75', ax = i)
    sns.distplot(df[c][df['Class'] == 1], color = '#b94646', ax = i)
f.tight_layout()

# %%
f, (ax1, ax2) = plt.subplots(2, 1, figsize = (12, 6))
plt.subplots_adjust(hspace = 0.5)
ax1.hist(df['Time'][df['Class'] == 0], bins = 50, color = 'crimson' ,alpha = 0.85)

ax1.set_xlabel('Time in secs')
ax1.set_title('Not Fraud')
ax1.set_ylabel('Number of Transactions')


ax2.hist(df["Time"][df['Class'] == 1], bins = 50, color = 'darkblue', alpha = 0.8)

ax2.set_xlabel('Time in secs')
ax2.set_ylabel("Number of Transactions")
ax2.set_title('Fraud')
plt.show()

# %%
f, (ax1, ax2) = plt.subplots(2, 1, figsize = (12, 6))
plt.subplots_adjust(hspace = 0.5)
ax1.hist(df['Amount'][df['Class'] == 0], bins = 50, color = 'crimson' ,alpha = 0.85)
ax1.set_xlabel('Amount')
ax1.set_title('Not Fraud')
ax1.set_ylabel('Number of Transactions')


ax2.hist(df["Amount"][df['Class'] == 1], bins = 50, color = 'darkblue', alpha = 0.8)
ax2.set_xlabel('Amount')
ax2.set_ylabel("Number of Transactions")
ax2.set_title('Fraud')
plt.show()

# %%
X = df.drop(['Time', 'Class'], axis = 1)
y = df['Class']

# %%
scaler = StandardScaler()
X['Amount'] = scaler.fit_transform(X[['Amount']])

# %%
X.head()
# Out:
#          V1        V2        V3        V4        V5        V6        V7  \
# 0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9       V10  ...       V20       V21       V22       V23  \
# 0  0.098698  0.363787  0.090794  ...  0.251412 -0.018307  0.277838 -0.110474
# 1  0.085102 -0.255425 -0.166974  ... -0.069083 -0.225775 -0.638672  0.101288
# 2  0.247676 -1.514654  0.207643  ...  0.524980  0.247998  0.771679  0.909412
# 3  0.377436 -1.387024 -0.054952  ... -0.208038 -0.108300  0.005274 -0.190321
# 4 -0.270533  0.817739  0.753074  ...  0.408542 -0.009431  0.798278 -0.137458
#
#         V24       V25       V26       V27       V28    Amount
# 0  0.066928  0.128539 -0.189115  0.133558 -0.021053  0.244964
# 1 -0.339846  0.167170  0.125895 -0.008983  0.014724 -0.342475
# 2 -0.689281 -0.327642 -0.139097 -0.055353 -0.059752  1.160686
# 3 -1.175575  0.647376 -0.221929  0.062723  0.061458  0.140534
# 4  0.141267 -0.206010  0.502292  0.219422  0.215153 -0.073403
#
# [5 rows x 29 columns]
#          V1        V2        V3        V4        V5        V6        V7  \
# 0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9       V10  ...       V20       V21       V22       V23  \
# 0  0.098698  0.363787  0.090794  ...  0.251412 -0.018307  0.277838 -0.110474
# 1  0.085102 -0.255425 -0.166974  ... -0.069083 -0.225775 -0.638672  0.101288
# 2  0.247676 -1.514654  0.207643  ...  0.524980  0.247998  0.771679  0.909412
# 3  0.377436 -1.387024 -0.054952  ... -0.208038 -0.108300  0.005274 -0.190321
# 4 -0.270533  0.817739  0.753074  ...  0.408542 -0.009431  0.798278 -0.137458
#
#         V24       V25       V26       V27       V28    Amount
# 0  0.066928  0.128539 -0.189115  0.133558 -0.021053  0.244964
# 1 -0.339846  0.167170  0.125895 -0.008983  0.014724 -0.342475
# 2 -0.689281 -0.327642 -0.139097 -0.055353 -0.059752  1.160686
# 3 -1.175575  0.647376 -0.221929  0.062723  0.061458  0.140534
# 4  0.141267 -0.206010  0.502292  0.219422  0.215153 -0.073403
#
# [5 rows x 29 columns]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, stratify = y)
X_train, X_valid, y_train, y_valid = train_test_split(X_train, y_train, test_size = 0.2, stratify = y_train)

# %%
def is_balanced_splitting(y):
    counts = np.bincount(y)
    return counts[1] / (sum(counts))

# %%
print('Percentage of FRAUD instances in Training Set : {}'.format(is_balanced_splitting(y_train) * 100))
print('Percentage of FRAUD instances in Testing Set : {}'.format(is_balanced_splitting(y_test) * 100))
print('Percentage of FRAUD instances in Validation set : {}'.format(is_balanced_splitting(y_valid) * 100))
# Out:
# Percentage of FRAUD instances in Training Set : 0.17281485220215498
# Percentage of FRAUD instances in Testing Set : 0.17204452090867595
# Percentage of FRAUD instances in Validation set : 0.1733634707805745
# Percentage of FRAUD instances in Training Set : 0.17281485220215498
# Percentage of FRAUD instances in Testing Set : 0.17204452090867595
# Percentage of FRAUD instances in Validation set : 0.1733634707805745

# %%
X_train.shape
# Out:
# (182276, 29)
# (182276, 29)

# %% [markdown]
# ### Oversampling

# %%
def oversampling(X_train, y_train):
# Oversampling the imbalanced dataset
    oversample = SMOTE(random_state = 42, sampling_strategy = 0.4)
    X, y = oversample.fit_resample(X_train, y_train)
    # summarize the new class distribution
    counter = Counter(y)
    print(counter)
    return X, y
    # scatter plot of examples by class label

# %%
X_train, y_train = oversampling(X_train, y_train)
# Out:
# Counter({0: 181961, 1: 72784})
# Counter({0: 181961, 1: 72784})

# %% [markdown]
# Now, it's fairly balanced data

# %%
sns.set(style="whitegrid")
labels = ['Not Fraud', 'Fraud']
sizes = y_train.value_counts()

colors = ["lightblue","red"]


plt.figure(figsize=(7,7))
plt.pie(sizes, labels=labels, colors=colors, autopct='%1.1f%%', startangle=90,)

plt.title('Frauds in the dataset')
plt.legend()
plt.show()

# %% [markdown]
# ### Adding Gaussian Noise

# %%
#Adding Gaussian Noise

def add_noise(X_train):
    mean = 0
    sigma = 0.1
    noise = np.random.normal(mean, sigma ,X_train.shape)
    X_train = X_train + noise
    return X_train

# %%
X_train_noised = add_noise(X_train)

# %%
y_train = np.array(y_train).reshape(-1, 1)
y_valid = np.array(y_valid).reshape(-1, 1)
y_test = np.array(y_test).reshape(-1, 1)

# %%
#from keras.utils import np_utils

#y_train = np_utils.to_categorical(y_train)
#y_test = np_utils.to_categorical(y_test)
#y_valid = np_utils.to_categorical(y_valid)

# Instead of:
# from keras.utils import np_utils
# y_train = np_utils.to_categorical(y_train)

# Use:
y_train = keras.utils.to_categorical(y_train)
y_test = keras.utils.to_categorical(y_test)
y_valid = keras.utils.to_categorical(y_valid)

# %% [markdown]
# ### Autoencoder Model

# %%
epochs = 25
batch_size = 128
input_shape = X_train.shape[1] #num of columns, 29
lr = 1e-7

#Autoencoder Model
input_layer = keras.layers.Input(shape=(input_shape, ))
encoder = keras.layers.Dense(128, activation = "relu", activity_regularizer = keras.regularizers.l1(lr),
                             kernel_initializer = 'lecun_normal')(input_layer)
encoder = keras.layers.Dense(64, activation = "relu")(encoder)
encoder = keras.layers.Dense(32, activation = 'relu')(encoder)
decoder = keras.layers.Dense(32, activation = 'relu')(encoder)
decoder = keras.layers.Dense(64, activation = 'relu')(decoder)
decoder = keras.layers.Dense(128, activation = 'relu')(decoder)
decoder = keras.layers.Dense(29, activation = 'relu')(decoder)
autoencoder = keras.Model(inputs=input_layer, outputs=decoder)

# %%
autoencoder.compile(metrics = ['accuracy'],
                    loss = 'mean_squared_error',
                    optimizer = 'adam')


history = autoencoder.fit(X_train_noised, X_train_noised,
                    epochs = epochs,
                    batch_size = batch_size,
                    shuffle = True,
                    validation_data = (X_valid, X_valid),
                    verbose=1).history
# Out:
# Epoch 1/25
# 1991/1991 ━━━━━━━━━━━━━━━━━━━━ 14s 5ms/step - accuracy: 0.5466 - loss: 7.4567 - val_accuracy: 0.7563 - val_loss: 0.7594
# Epoch 2/25
# 1991/1991 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.7939 - loss: 7.1815 - val_accuracy: 0.7790 - val_loss: 0.7475
# Epoch 3/25
# 1991/1991 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.8143 - loss: 7.2033 - val_accuracy: 0.7884 - val_loss: 0.7339
# Epoch 4/25
# 1991/1991 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.8392 - loss: 7.1043 - val_accuracy: 0.8108 - val_loss: 0.7301
# Epoch 5/25
# 1991/1991 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.8444 - loss: 7.1083 - val_accuracy: 0.8011 - val_loss: 0.7304
# Epoch 6/25
# 1991/1991 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.8505 - loss: 7.1414 - val_accuracy: 0.8072 - val_loss: 0.7303
# Epoch 7/25
# 1991/1991 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.8570 - loss: 7.0390 - val_accuracy: 0.8258 - val_loss: 0.7281
# Epoch 8/25
# 1991/1991 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.8608 - loss: 7.1506 - val_accuracy: 0.8280 - val_loss: 0.7278
# Epoch 9/25
# 1991/1991 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.8595 - loss: 7.1550 - val_accuracy: 0.8228 - val_loss: 0.7271
# Epoch 10/25
# 1991/1991 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.8615 - loss: 7.1416 - val_accuracy: 0.8296 - val_loss: 0.7262
# Epoch 11/25
# 1991/1991 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.8644 - loss: 7.1423 - val_accuracy: 0.8293 - val_loss: 0.7262
# Epoch 12/25
# 1991/1991 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.8653 - loss: 7.1063 - val_accuracy: 0.8097 - val_loss: 0.7280
# Epoch 13/25
# 1991/1991 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.8593 - loss: 7.1246 - val_accuracy: 0.8152 - val_loss: 0.7268
# Epoch 14/25
# 1991/1991 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - accuracy: 0.8675 - loss: 7.0809 - val_accuracy: 0.8218 - val_loss: 0.7263
# Epoch 15/25
# 1991/1991 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - accuracy: 0.8699 - loss: 7.0878 - val_accuracy: 0.8290 - val_loss: 0.7275
# Epoch 16/25
# 1991/1991 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.8695 - loss: 7.0234 - val_accuracy: 0.8399 - val_loss: 0.7270
# Epoch 17/25
# 1991/1991 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.8721 - loss: 7.1482 - val_accuracy: 0.8322 - val_loss: 0.7274
# Epoch 18/25
# 1991/1991 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.8746 - loss: 7.1335 - val_accuracy: 0.8407 - val_loss: 0.7270
# Epoch 19/25
# 1991/1991 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.8747 - loss: 7.1350 - val_accuracy: 0.8388 - val_loss: 0.7269
# Epoch 20/25
# 1991/1991 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - accuracy: 0.8709 - loss: 7.1076 - val_accuracy: 0.8399 - val_loss: 0.7271
# Epoch 21/25
# 1991/1991 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.8703 - loss: 7.1257 - val_accuracy: 0.8437 - val_loss: 0.7268
# Epoch 22/25
# 1991/1991 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.8749 - loss: 7.1206 - val_accuracy: 0.8394 - val_loss: 0.7371
# Epoch 23/25
# 1991/1991 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.8741 - loss: 7.1622 - val_accuracy: 0.8387 - val_loss: 0.7372
# Epoch 24/25
# 1991/1991 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - accuracy: 0.8735 - loss: 7.0915 - val_accuracy: 0.8119 - val_loss: 0.7294
# Epoch 25/25
# 1991/1991 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.8724 - loss: 7.1153 - val_accuracy: 0.8146 - val_loss: 0.7281
# Epoch 1/25
# 1991/1991 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - accuracy: 0.4563 - loss: 7.0409 - val_accuracy: 0.4169 - val_loss: 0.8565
# Epoch 2/25
# 1991/1991 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.5695 - loss: 6.9197 - val_accuracy: 0.4125 - val_loss: 0.8490
# Epoch 3/25
# 1991/1991 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.5780 - loss: 6.9278 - val_accuracy: 0.4272 - val_loss: 0.8391
# Epoch 4/25
# 1991/1991 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.5805 - loss: 6.9429 - val_accuracy: 0.4335 - val_loss: 0.8375
# Epoch 5/25
# 1991/1991 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - accuracy: 0.5829 - loss: 6.9481 - val_accuracy: 0.4349 - val_loss: 0.8373
# Epoch 6/25
# 1991/1991 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.5860 - loss: 6.8576 - val_accuracy: 0.4363 - val_loss: 0.8376
# Epoch 7/25
# 1991/1991 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.5860 - loss: 6.9631 - val_accuracy: 0.4370 - val_loss: 0.8364
# Epoch 8/25
# 1991/1991 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - accuracy: 0.5907 - loss: 6.9490 - val_accuracy: 0.4416 - val_loss: 0.8359
# Epoch 9/25
# 1991/1991 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.5888 - loss: 6.9080 - val_accuracy: 0.4418 - val_loss: 0.8358
# Epoch 10/25
# 1991/1991 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.5903 - loss: 6.9377 - val_accuracy: 0.4390 - val_loss: 0.8360
# Epoch 11/25
# 1991/1991 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.5996 - loss: 6.9185 - val_accuracy: 0.5052 - val_loss: 0.7909
# Epoch 12/25
# 1991/1991 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - accuracy: 0.6369 - loss: 6.8942 - val_accuracy: 0.5066 - val_loss: 0.7904
# Epoch 13/25
# 1991/1991 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - accuracy: 0.6387 - loss: 6.9073 - val_accuracy: 0.5091 - val_loss: 0.7902
# Epoch 14/25
# 1991/1991 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.6410 - loss: 6.9531 - val_accuracy: 0.5074 - val_loss: 0.7902
# Epoch 15/25
# 1991/1991 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.6394 - loss: 6.8443 - val_accuracy: 0.5043 - val_loss: 0.7909
# Epoch 16/25
# 1991/1991 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.6404 - loss: 6.9137 - val_accuracy: 0.5084 - val_loss: 0.7902
# Epoch 17/25
# 1991/1991 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.6398 - loss: 6.9614 - val_accuracy: 0.5060 - val_loss: 0.7915
# Epoch 18/25
# 1991/1991 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.6401 - loss: 6.8642 - val_accuracy: 0.5083 - val_loss: 0.7904
# Epoch 19/25
# 1991/1991 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.6427 - loss: 6.9402 - val_accuracy: 0.5086 - val_loss: 0.7901
# Epoch 20/25
# 1991/1991 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.6425 - loss: 6.8980 - val_accuracy: 0.5104 - val_loss: 0.7900
# Epoch 21/25
# 1980/1991 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6391 - loss: 6.9778

# %%
denoised_data = autoencoder.predict(X_train_noised)
# Out:
# 7961/7961 ━━━━━━━━━━━━━━━━━━━━ 13s 2ms/step

# %% [markdown]
# # Fraud Detector Model (Baseline)

# %%
epochs = 25
batch_size = 256
input_shape = X_train.shape[1] #num of columns, 29


input_layer = keras.layers.Input(shape = (input_shape, ))
layer_1 = keras.layers.Dense(128, activation = "relu",
                            kernel_initializer = 'lecun_normal')(input_layer)
layer_2 = keras.layers.Dense(64, activation = "relu", kernel_initializer = 'lecun_normal')(layer_1)
layer_3 = keras.layers.Dense(32, activation = 'relu', kernel_initializer = 'lecun_normal')(layer_2)
layer_4 = keras.layers.Dense(16, activation = 'relu', kernel_initializer = 'lecun_normal')(layer_3)
output_layer = keras.layers.Dense(2, activation = 'sigmoid')(layer_4)
fraud_dtr = keras.Model(inputs = input_layer, outputs = output_layer)

# %%
fraud_dtr.compile(metrics=['accuracy'],
                    loss='binary_crossentropy',
                    optimizer='sgd')

#callback = keras.callbacks.ModelCheckpoint('Fraud_Detector_model.h5',
#                                          save_best_only = True)
callback = keras.callbacks.ModelCheckpoint('Fraud_Detector_model.keras',
                                          save_best_only = True)

history = fraud_dtr.fit(denoised_data, y_train,
                    epochs = epochs,
                    batch_size  = 256,
                    validation_data = (X_valid, y_valid),
                    callbacks = [callback]).history
# Out:
# Epoch 1/25
# 996/996 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9054 - loss: 0.3910 - val_accuracy: 0.9453 - val_loss: 0.1789
# Epoch 2/25
# 996/996 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - accuracy: 0.9536 - loss: 0.1310 - val_accuracy: 0.9409 - val_loss: 0.1814
# Epoch 3/25
# 996/996 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9564 - loss: 0.1184 - val_accuracy: 0.9309 - val_loss: 0.2006
# Epoch 4/25
# 996/996 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9587 - loss: 0.1087 - val_accuracy: 0.9411 - val_loss: 0.1744
# Epoch 5/25
# 996/996 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9614 - loss: 0.0999 - val_accuracy: 0.9258 - val_loss: 0.2160
# Epoch 6/25
# 996/996 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9639 - loss: 0.0906 - val_accuracy: 0.9341 - val_loss: 0.1996
# Epoch 7/25
# 996/996 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9681 - loss: 0.0810 - val_accuracy: 0.9362 - val_loss: 0.2012
# Epoch 8/25
# 996/996 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9707 - loss: 0.0732 - val_accuracy: 0.9413 - val_loss: 0.1927
# Epoch 9/25
# 996/996 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9755 - loss: 0.0639 - val_accuracy: 0.9423 - val_loss: 0.1937
# Epoch 10/25
# 996/996 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9778 - loss: 0.0577 - val_accuracy: 0.9523 - val_loss: 0.1687
# Epoch 11/25
# 996/996 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9816 - loss: 0.0508 - val_accuracy: 0.9547 - val_loss: 0.1663
# Epoch 12/25
# 996/996 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9836 - loss: 0.0457 - val_accuracy: 0.9541 - val_loss: 0.1729
# Epoch 13/25
# 996/996 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9859 - loss: 0.0418 - val_accuracy: 0.9603 - val_loss: 0.1559
# Epoch 14/25
# 996/996 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9868 - loss: 0.0381 - val_accuracy: 0.9672 - val_loss: 0.1345
# Epoch 15/25
# 996/996 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9886 - loss: 0.0345 - val_accuracy: 0.9686 - val_loss: 0.1342
# Epoch 16/25
# 996/996 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9897 - loss: 0.0314 - val_accuracy: 0.9724 - val_loss: 0.1213
# Epoch 17/25
# 996/996 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9906 - loss: 0.0290 - val_accuracy: 0.9791 - val_loss: 0.0951
# Epoch 18/25
# 996/996 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9907 - loss: 0.0273 - val_accuracy: 0.9789 - val_loss: 0.0971
# Epoch 19/25
# 996/996 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9920 - loss: 0.0262 - val_accuracy: 0.9785 - val_loss: 0.1027
# Epoch 20/25
# 996/996 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9923 - loss: 0.0243 - val_accuracy: 0.9812 - val_loss: 0.0930
# Epoch 21/25
# 996/996 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9928 - loss: 0.0237 - val_accuracy: 0.9803 - val_loss: 0.0997
# Epoch 22/25
# 996/996 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9932 - loss: 0.0224 - val_accuracy: 0.9793 - val_loss: 0.1048
# Epoch 23/25
# 996/996 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9936 - loss: 0.0214 - val_accuracy: 0.9848 - val_loss: 0.0791
# Epoch 24/25
# 996/996 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9941 - loss: 0.0202 - val_accuracy: 0.9831 - val_loss: 0.0881
# Epoch 25/25
# 996/996 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9942 - loss: 0.0194 - val_accuracy: 0.9882 - val_loss: 0.0664

# %% [markdown]
# ## Model Evaluation

# %%
#Load the best saved model

model = keras.models.load_model('Fraud_Detector_model.keras')

# %%
model.evaluate(X_test, y_test)
# Out:
# 1781/1781 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9888 - loss: 0.0608
# [0.06368756294250488, 0.9888170957565308]

# %%
baseline_preds = model.predict(X_test)
# Out:
# 1781/1781 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step

# %% [markdown]
# #### ROC-AUC Curve

# %%
#Plotting the ROC-AUC Curve

false_pos_rate, true_pos_rate, thresholds = roc_curve(y_test.argmax(axis = 1), baseline_preds[:,1])
roc_auc = auc(false_pos_rate, true_pos_rate,)

plt.plot(false_pos_rate, true_pos_rate, linewidth = 5, label = 'AUC = %0.3f'% roc_auc)
plt.plot([0,1],[0,1], linewidth = 5)

plt.xlim([-0.01, 1])
plt.ylim([0, 1.01])
plt.legend(loc='lower right')
plt.title('Receiver operating characteristic curve (ROC)')
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show()

# %% [markdown]
# #### Recall

# %%
print('Percentage of correctly predicting the Fraud Transactions : ', recall_score(y_test.argmax(axis = 1), baseline_preds.argmax(axis = 1)) * 100, '%')
# Out:
# Percentage of correctly predicting the Fraud Transactions :  86.73469387755102 %

# %% [markdown]
# #### PR-AUC Curve

# %%
from sklearn.metrics import precision_recall_curve
from sklearn.metrics import auc

precision, recall, thresholds = precision_recall_curve(y_test.argmax(axis = 1), baseline_preds[:,1])
pr_auc = auc(recall, precision)

plt.plot(recall, precision, linewidth = 5, label = 'AUC = %0.3f'% pr_auc)

plt.xlim([-0.01, 1.01])
plt.ylim([0, 1.01])
plt.legend(loc='lower right')
plt.title('Precision Recall Curve')
plt.ylabel('Precision')
plt.xlabel('Recall')
plt.show()

# %% [markdown]
# # Measuring the Effect of Denoising Autoencoder

# %% [markdown]
# In this section we will train the model on X_train, instead of denoised_data, and see the difference in perforemance between the models

# %%
epochs = 25
batch_size = 128
input_shape = X_train.shape[1] #num of columns, 29
lr = 1e-7

#Autoencoder Model
input_layer = keras.layers.Input(shape=(input_shape, ))
encoder = keras.layers.Dense(128, activation = "relu", activity_regularizer = keras.regularizers.l1(lr),
                             kernel_initializer = 'lecun_normal')(input_layer)
encoder = keras.layers.Dense(64, activation = "relu")(encoder)
encoder = keras.layers.Dense(32, activation = 'relu')(encoder)
decoder = keras.layers.Dense(32, activation = 'relu')(encoder)
decoder = keras.layers.Dense(64, activation = 'relu')(decoder)
decoder = keras.layers.Dense(128, activation = 'relu')(decoder)
decoder = keras.layers.Dense(29, activation = 'relu')(decoder)
autoencoder = keras.Model(inputs=input_layer, outputs=decoder)

# %%
fraud_dtr.compile(metrics=['accuracy'],
                    loss='binary_crossentropy',
                    optimizer='sgd')

#callback = keras.callbacks.ModelCheckpoint('Fraud_Detector_model.h5',
#                                          save_best_only = True)
callback = keras.callbacks.ModelCheckpoint('Fraud_Detector_model.keras',
                                          save_best_only = True)

history = fraud_dtr.fit(X_train_noised, y_train,
                    epochs = epochs,
                    batch_size  = 256,
                    validation_data = (X_valid, y_valid),
                    callbacks = [callback]).history
# Out:
# Epoch 1/25
# 996/996 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.9780 - loss: 0.0763 - val_accuracy: 0.9912 - val_loss: 0.0261
# Epoch 2/25
# 996/996 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.9912 - loss: 0.0265 - val_accuracy: 0.9939 - val_loss: 0.0201
# Epoch 3/25
# 996/996 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9943 - loss: 0.0194 - val_accuracy: 0.9951 - val_loss: 0.0174
# Epoch 4/25
# 996/996 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9957 - loss: 0.0154 - val_accuracy: 0.9964 - val_loss: 0.0143
# Epoch 5/25
# 996/996 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9966 - loss: 0.0134 - val_accuracy: 0.9965 - val_loss: 0.0136
# Epoch 6/25
# 996/996 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9971 - loss: 0.0113 - val_accuracy: 0.9965 - val_loss: 0.0135
# Epoch 7/25
# 996/996 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9974 - loss: 0.0105 - val_accuracy: 0.9962 - val_loss: 0.0146
# Epoch 8/25
# 996/996 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9975 - loss: 0.0098 - val_accuracy: 0.9969 - val_loss: 0.0129
# Epoch 9/25
# 996/996 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9980 - loss: 0.0088 - val_accuracy: 0.9971 - val_loss: 0.0125
# Epoch 10/25
# 996/996 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9982 - loss: 0.0077 - val_accuracy: 0.9973 - val_loss: 0.0122
# Epoch 11/25
# 996/996 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9983 - loss: 0.0075 - val_accuracy: 0.9975 - val_loss: 0.0114
# Epoch 12/25
# 996/996 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9985 - loss: 0.0070 - val_accuracy: 0.9979 - val_loss: 0.0108
# Epoch 13/25
# 996/996 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9985 - loss: 0.0063 - val_accuracy: 0.9974 - val_loss: 0.0120
# Epoch 14/25
# 996/996 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.9986 - loss: 0.0063 - val_accuracy: 0.9982 - val_loss: 0.0104
# Epoch 15/25
# 996/996 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9988 - loss: 0.0061 - val_accuracy: 0.9983 - val_loss: 0.0103
# Epoch 16/25
# 996/996 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9988 - loss: 0.0052 - val_accuracy: 0.9981 - val_loss: 0.0108
# Epoch 17/25
# 996/996 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9989 - loss: 0.0052 - val_accuracy: 0.9987 - val_loss: 0.0093
# Epoch 18/25
# 996/996 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9988 - loss: 0.0053 - val_accuracy: 0.9979 - val_loss: 0.0111
# Epoch 19/25
# 996/996 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9989 - loss: 0.0051 - val_accuracy: 0.9982 - val_loss: 0.0107
# Epoch 20/25
# 996/996 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9989 - loss: 0.0048 - val_accuracy: 0.9981 - val_loss: 0.0111
# Epoch 21/25
# 996/996 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.9990 - loss: 0.0046 - val_accuracy: 0.9982 - val_loss: 0.0107
# Epoch 22/25
# 996/996 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9991 - loss: 0.0039 - val_accuracy: 0.9988 - val_loss: 0.0092
# Epoch 23/25
# 996/996 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9989 - loss: 0.0047 - val_accuracy: 0.9982 - val_loss: 0.0103
# Epoch 24/25
# 996/996 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9991 - loss: 0.0040 - val_accuracy: 0.9981 - val_loss: 0.0112
# Epoch 25/25
# 996/996 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9992 - loss: 0.0037 - val_accuracy: 0.9983 - val_loss: 0.0103

# %%
#Load the best saved model

model = keras.models.load_model('Fraud_Detector_model.keras')

# %%
model.evaluate(X_test, y_test)
# Out:
# 1781/1781 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9990 - loss: 0.0056
# [0.005765640176832676, 0.9991046786308289]

# %%
no_noise_preds = model.predict(X_test)
# Out:
# 1781/1781 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step

# %% [markdown]
# ## Model Evaluation

# %% [markdown]
# #### ROC-AUC Curve

# %%
#Plotting the ROC-AUC Curve

false_pos_rate, true_pos_rate, thresholds = roc_curve(y_test.argmax(axis = 1), no_noise_preds[:,1])
roc_auc = auc(false_pos_rate, true_pos_rate,)

plt.plot(false_pos_rate, true_pos_rate, linewidth = 5, label = 'AUC = %0.3f'% roc_auc)
plt.plot([0,1],[0,1], linewidth = 5)

plt.xlim([-0.01, 1])
plt.ylim([0, 1.01])
plt.legend(loc='lower right')
plt.title('Receiver operating characteristic curve (ROC)')
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show()

# %% [markdown]
# #### Recall

# %%
print('Percentage of correctly predicting the Fraud Transactions : ', recall_score(y_test.argmax(axis = 1), no_noise_preds.argmax(axis = 1)) * 100, '%')
# Out:
# Percentage of correctly predicting the Fraud Transactions :  86.73469387755102 %

# %% [markdown]
# #### PR-AUC Curve

# %%
precision, recall, thresholds = precision_recall_curve(y_test.argmax(axis = 1), no_noise_preds[:,1])
pr_auc = auc(recall, precision)

plt.plot(recall, precision, linewidth = 5, label = 'AUC = %0.3f'% pr_auc)

plt.xlim([-0.01, 1.01])
plt.ylim([0, 1.01])
plt.legend(loc='lower right')
plt.title('Precision Recall Curve')
plt.ylabel('Precision')
plt.xlabel('Recall')
plt.show()

# %% [markdown]
# # Applying PR AUC instead of Accuracy

# %% [markdown]
# The PR AUC was calculated with code taken from here:
#
# https://www.kaggle.com/code/nyk510/using-pr-auc-metrics-in-keras

# %%
from tensorflow.keras.metrics import AUC
pr_metric = AUC(curve='PR', num_thresholds=1000) # The higher the threshold value, the more accurate it is calculated.

import tensorflow as tf
from sklearn.metrics import average_precision_score

def sk_pr_auc(y_true, y_pred):
    return tf.py_function(average_precision_score, (y_true, y_pred), tf.float64)

model.compile(loss='binary_crossentropy', optimizer='adam',
              metrics=[
                  pr_metric,
                  sk_pr_auc
              ])

# %%
epochs = 25
batch_size = 256
input_shape = X_train.shape[1] #num of columns, 29


input_layer = keras.layers.Input(shape = (input_shape, ))
layer_1 = keras.layers.Dense(128, activation = "relu",
                            kernel_initializer = 'lecun_normal')(input_layer)
layer_2 = keras.layers.Dense(64, activation = "relu", kernel_initializer = 'lecun_normal')(layer_1)
layer_3 = keras.layers.Dense(32, activation = 'relu', kernel_initializer = 'lecun_normal')(layer_2)
layer_4 = keras.layers.Dense(16, activation = 'relu', kernel_initializer = 'lecun_normal')(layer_3)
output_layer = keras.layers.Dense(2, activation = 'sigmoid')(layer_4)
fraud_dtr = keras.Model(inputs = input_layer, outputs = output_layer)

# %%
fraud_dtr.compile(metrics=[pr_metric],
                    loss='binary_crossentropy',
                    optimizer='sgd')

#callback = keras.callbacks.ModelCheckpoint('Fraud_Detector_model.h5',
#                                          save_best_only = True)
callback = keras.callbacks.ModelCheckpoint('Fraud_Detector_model.keras',
                                          save_best_only = True)

history = fraud_dtr.fit(X_train_noised, y_train,
                    epochs = epochs,
                    batch_size  = 256,
                    validation_data = (X_valid, y_valid),
                    callbacks = [callback]).history
# Out:
# Epoch 1/25
# 996/996 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step - auc: 0.9681 - loss: 0.2568 - val_auc: 0.9989 - val_loss: 0.0457
# Epoch 2/25
# 996/996 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - auc: 0.9956 - loss: 0.0810 - val_auc: 0.9989 - val_loss: 0.0394
# Epoch 3/25
# 996/996 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - auc: 0.9971 - loss: 0.0656 - val_auc: 0.9990 - val_loss: 0.0346
# Epoch 4/25
# 996/996 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - auc: 0.9978 - loss: 0.0571 - val_auc: 0.9992 - val_loss: 0.0279
# Epoch 5/25
# 996/996 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - auc: 0.9985 - loss: 0.0480 - val_auc: 0.9992 - val_loss: 0.0272
# Epoch 6/25
# 996/996 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - auc: 0.9990 - loss: 0.0407 - val_auc: 0.9993 - val_loss: 0.0239
# Epoch 7/25
# 996/996 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - auc: 0.9992 - loss: 0.0353 - val_auc: 0.9994 - val_loss: 0.0200
# Epoch 8/25
# 996/996 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - auc: 0.9994 - loss: 0.0299 - val_auc: 0.9993 - val_loss: 0.0219
# Epoch 9/25
# 996/996 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - auc: 0.9995 - loss: 0.0275 - val_auc: 0.9994 - val_loss: 0.0203
# Epoch 10/25
# 996/996 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - auc: 0.9996 - loss: 0.0234 - val_auc: 0.9994 - val_loss: 0.0181
# Epoch 11/25
# 996/996 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - auc: 0.9996 - loss: 0.0217 - val_auc: 0.9995 - val_loss: 0.0174
# Epoch 12/25
# 996/996 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - auc: 0.9997 - loss: 0.0194 - val_auc: 0.9994 - val_loss: 0.0198
# Epoch 13/25
# 996/996 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - auc: 0.9997 - loss: 0.0170 - val_auc: 0.9995 - val_loss: 0.0157
# Epoch 14/25
# 996/996 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - auc: 0.9997 - loss: 0.0159 - val_auc: 0.9995 - val_loss: 0.0170
# Epoch 15/25
# 996/996 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - auc: 0.9997 - loss: 0.0151 - val_auc: 0.9995 - val_loss: 0.0134
# Epoch 16/25
# 996/996 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - auc: 0.9997 - loss: 0.0133 - val_auc: 0.9995 - val_loss: 0.0142
# Epoch 17/25
# 996/996 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - auc: 0.9998 - loss: 0.0117 - val_auc: 0.9995 - val_loss: 0.0129
# Epoch 18/25
# 996/996 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - auc: 0.9998 - loss: 0.0112 - val_auc: 0.9995 - val_loss: 0.0126
# Epoch 19/25
# 996/996 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - auc: 0.9998 - loss: 0.0110 - val_auc: 0.9995 - val_loss: 0.0125
# Epoch 20/25
# 996/996 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - auc: 0.9998 - loss: 0.0097 - val_auc: 0.9995 - val_loss: 0.0125
# Epoch 21/25
# 996/996 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - auc: 0.9998 - loss: 0.0094 - val_auc: 0.9995 - val_loss: 0.0118
# Epoch 22/25
# 996/996 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - auc: 0.9998 - loss: 0.0089 - val_auc: 0.9995 - val_loss: 0.0114
# Epoch 23/25
# 996/996 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - auc: 0.9998 - loss: 0.0082 - val_auc: 0.9995 - val_loss: 0.0118
# Epoch 24/25
# 996/996 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - auc: 0.9999 - loss: 0.0076 - val_auc: 0.9996 - val_loss: 0.0114
# Epoch 25/25
# 996/996 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - auc: 0.9999 - loss: 0.0069 - val_auc: 0.9996 - val_loss: 0.0108

# %% [markdown]
# ## Model Evaluation

# %%
#Load the best saved model

model = keras.models.load_model('Fraud_Detector_model.keras')

# %%
model.evaluate(X_test, y_test)
# Out:
# 1781/1781 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - auc: 0.9996 - loss: 0.0087
# [0.00821938831359148, 0.9997765421867371]

# %%
pr_auc_preds = model.predict(X_test)
# Out:
# 1781/1781 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step

# %% [markdown]
# #### ROC-AUC Curve

# %%
#Plotting the ROC-AUC Curve

false_pos_rate, true_pos_rate, thresholds = roc_curve(y_test.argmax(axis = 1), pr_auc_preds[:,1])
roc_auc = auc(false_pos_rate, true_pos_rate,)

plt.plot(false_pos_rate, true_pos_rate, linewidth = 5, label = 'AUC = %0.3f'% roc_auc)
plt.plot([0,1],[0,1], linewidth = 5)

plt.xlim([-0.01, 1])
plt.ylim([0, 1.01])
plt.legend(loc='lower right')
plt.title('Receiver operating characteristic curve (ROC)')
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show()

# %% [markdown]
# #### Recall

# %%
print('Percentage of correctly predicting the Fraud Transactions : ', recall_score(y_test.argmax(axis = 1), pr_auc_preds.argmax(axis = 1)) * 100, '%')
# Out:
# Percentage of correctly predicting the Fraud Transactions :  88.77551020408163 %

# %% [markdown]
# #### PR-AUC Curve

# %%
precision, recall, thresholds = precision_recall_curve(y_test.argmax(axis = 1), pr_auc_preds[:,1])
pr_auc = auc(recall, precision)

plt.plot(recall, precision, linewidth = 5, label = 'AUC = %0.3f'% pr_auc)

plt.xlim([-0.01, 1.01])
plt.ylim([0, 1.01])
plt.legend(loc='lower right')
plt.title('Precision Recall Curve')
plt.ylabel('Precision')
plt.xlabel('Recall')
plt.show()

# %% [markdown]
# # Improved Fraud detector

# %%
from tensorflow.keras import regularizers

input_layer = keras.layers.Input(shape=(input_shape,))
layer_1 = keras.layers.Dense(128, activation="relu",
                             kernel_initializer='he_normal')(input_layer)
drop_1 = keras.layers.Dropout(0.2)(layer_1)

layer_2 = keras.layers.Dense(64, activation="relu",
                             kernel_initializer='he_normal')(drop_1)
drop_2 = keras.layers.Dropout(0.2)(layer_2)

layer_3 = keras.layers.Dense(32, activation='relu',
                             kernel_initializer='he_normal')(drop_2)
layer_4 = keras.layers.Dense(16, activation='relu',
                             kernel_initializer='he_normal')(layer_3)
output_layer = keras.layers.Dense(2, activation='sigmoid')(layer_4)

fraud_dtr = keras.Model(inputs=input_layer, outputs=output_layer)

# %%
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau

early_stop = EarlyStopping(monitor='val_loss', patience=3, restore_best_weights=True)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=2)

fraud_dtr.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
history = fraud_dtr.fit(X_train_noised, y_train, epochs=25, batch_size=256,
              validation_split=0.2, callbacks=[early_stop, reduce_lr],validation_data = (X_valid, y_valid)).history
# Out:
# Epoch 1/25
# 996/996 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - accuracy: 0.9452 - loss: 0.1713 - val_accuracy: 0.9919 - val_loss: 0.0231 - learning_rate: 0.0010
# Epoch 2/25
# 996/996 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9885 - loss: 0.0323 - val_accuracy: 0.9954 - val_loss: 0.0144 - learning_rate: 0.0010
# Epoch 3/25
# 996/996 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.9938 - loss: 0.0187 - val_accuracy: 0.9971 - val_loss: 0.0133 - learning_rate: 0.0010
# Epoch 4/25
# 996/996 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9959 - loss: 0.0131 - val_accuracy: 0.9978 - val_loss: 0.0110 - learning_rate: 0.0010
# Epoch 5/25
# 996/996 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9971 - loss: 0.0107 - val_accuracy: 0.9981 - val_loss: 0.0111 - learning_rate: 0.0010
# Epoch 6/25
# 996/996 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9979 - loss: 0.0078 - val_accuracy: 0.9986 - val_loss: 0.0117 - learning_rate: 0.0010
# Epoch 7/25
# 996/996 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9980 - loss: 0.0073 - val_accuracy: 0.9985 - val_loss: 0.0122 - learning_rate: 5.0000e-04

# %%
fraud_dtr.compile(metrics=['accuracy'],
                    loss='binary_crossentropy',
                    optimizer='sgd')

#callback = keras.callbacks.ModelCheckpoint('Fraud_Detector_model.h5',
#                                          save_best_only = True)
callback = keras.callbacks.ModelCheckpoint('Fraud_Detector_model.keras',
                                          save_best_only = True)

history = fraud_dtr.fit(X_train_noised, y_train,
                    epochs = epochs,
                    batch_size  = 256,
                    validation_data = (X_valid, y_valid),
                    callbacks = [callback]).history
# Out:
# Epoch 1/25
# 996/996 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9970 - loss: 0.0099 - val_accuracy: 0.9977 - val_loss: 0.0112
# Epoch 2/25
# 996/996 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.9970 - loss: 0.0099 - val_accuracy: 0.9977 - val_loss: 0.0112
# Epoch 3/25
# 996/996 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9973 - loss: 0.0091 - val_accuracy: 0.9978 - val_loss: 0.0113
# Epoch 4/25
# 996/996 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9976 - loss: 0.0083 - val_accuracy: 0.9978 - val_loss: 0.0113
# Epoch 5/25
# 996/996 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9971 - loss: 0.0096 - val_accuracy: 0.9978 - val_loss: 0.0113
# Epoch 6/25
# 996/996 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9976 - loss: 0.0084 - val_accuracy: 0.9979 - val_loss: 0.0111
# Epoch 7/25
# 996/996 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9975 - loss: 0.0087 - val_accuracy: 0.9977 - val_loss: 0.0114
# Epoch 8/25
# 996/996 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.9975 - loss: 0.0080 - val_accuracy: 0.9978 - val_loss: 0.0113
# Epoch 9/25
# 996/996 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9975 - loss: 0.0087 - val_accuracy: 0.9978 - val_loss: 0.0113
# Epoch 10/25
# 996/996 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9974 - loss: 0.0087 - val_accuracy: 0.9978 - val_loss: 0.0112
# Epoch 11/25
# 996/996 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9976 - loss: 0.0080 - val_accuracy: 0.9979 - val_loss: 0.0113
# Epoch 12/25
# 996/996 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9975 - loss: 0.0082 - val_accuracy: 0.9979 - val_loss: 0.0113
# Epoch 13/25
# 996/996 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9976 - loss: 0.0079 - val_accuracy: 0.9979 - val_loss: 0.0113
# Epoch 14/25
# 996/996 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9979 - loss: 0.0079 - val_accuracy: 0.9978 - val_loss: 0.0114
# Epoch 15/25
# 996/996 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9975 - loss: 0.0080 - val_accuracy: 0.9978 - val_loss: 0.0114
# Epoch 16/25
# 996/996 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9975 - loss: 0.0087 - val_accuracy: 0.9980 - val_loss: 0.0113
# Epoch 17/25
# 996/996 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9977 - loss: 0.0079 - val_accuracy: 0.9980 - val_loss: 0.0113
# Epoch 18/25
# 996/996 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9975 - loss: 0.0079 - val_accuracy: 0.9980 - val_loss: 0.0113
# Epoch 19/25
# 996/996 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9978 - loss: 0.0073 - val_accuracy: 0.9981 - val_loss: 0.0113
# Epoch 20/25
# 996/996 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.9979 - loss: 0.0076 - val_accuracy: 0.9981 - val_loss: 0.0114
# Epoch 21/25
# 996/996 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9974 - loss: 0.0086 - val_accuracy: 0.9981 - val_loss: 0.0114
# Epoch 22/25
# 996/996 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9976 - loss: 0.0080 - val_accuracy: 0.9980 - val_loss: 0.0114
# Epoch 23/25
# 996/996 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9976 - loss: 0.0080 - val_accuracy: 0.9981 - val_loss: 0.0114
# Epoch 24/25
# 996/996 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9978 - loss: 0.0076 - val_accuracy: 0.9980 - val_loss: 0.0115
# Epoch 25/25
# 996/996 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9978 - loss: 0.0073 - val_accuracy: 0.9981 - val_loss: 0.0113

# %%
#Load the best saved model

model = keras.models.load_model('Fraud_Detector_model.keras')

# %%
model.evaluate(X_test, y_test)
# Out:
# 1781/1781 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9980 - loss: 0.0070
# [0.007488535717129707, 0.997963547706604]

# %%
trans_preds = model.predict(X_test)
# Out:
# 1781/1781 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step

# %% [markdown]
# ## Model Evaluation

# %% [markdown]
# #### ROC-AUC Curve

# %%
#Plotting the ROC-AUC Curve

false_pos_rate, true_pos_rate, thresholds = roc_curve(y_test.argmax(axis = 1), trans_preds[:,1])
roc_auc = auc(false_pos_rate, true_pos_rate,)

plt.plot(false_pos_rate, true_pos_rate, linewidth = 5, label = 'AUC = %0.3f'% roc_auc)
plt.plot([0,1],[0,1], linewidth = 5)

plt.xlim([-0.01, 1])
plt.ylim([0, 1.01])
plt.legend(loc='lower right')
plt.title('Receiver operating characteristic curve (ROC)')
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show()

# %% [markdown]
# #### Recall

# %%
print('Percentage of correctly predicting the Fraud Transactions : ', recall_score(y_test.argmax(axis = 1), trans_preds.argmax(axis = 1)) * 100, '%')
# Out:
# Percentage of correctly predicting the Fraud Transactions :  91.83673469387756 %

# %% [markdown]
# #### PR-AUC Curve

# %%
precision, recall, thresholds = precision_recall_curve(y_test.argmax(axis = 1), trans_preds[:,1])
pr_auc = auc(recall, precision)

plt.plot(recall, precision, linewidth = 5, label = 'AUC = %0.3f'% pr_auc)

plt.xlim([-0.01, 1.01])
plt.ylim([0, 1.01])
plt.legend(loc='lower right')
plt.title('Precision Recall Curve')
plt.ylabel('Precision')
plt.xlabel('Recall')
plt.show()

# %%
from sklearn.metrics import precision_recall_curve
from sklearn.metrics import auc
import matplotlib.pyplot as plt

# Assuming baseline_preds, no_noise_preds, and pr_auc_preds, and trans_preds are already defined from previous code blocks.
# And y_test is available.


models = {
    'Baseline Model': baseline_preds,
    'Denoising Removed': no_noise_preds,
    'PR AUC as a Loss Function': pr_auc_preds,
    'Transformer Architecture': trans_preds
}


plt.figure(figsize=(10, 8))

for model_name, predictions in models.items():
    precision, recall, thresholds = precision_recall_curve(y_test.argmax(axis=1), predictions[:, 1])
    pr_auc = auc(recall, precision)
    plt.plot(recall, precision, label=f'{model_name} (AUC = {pr_auc:.3f})', linewidth=2)

plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision-Recall Curves for Different Models')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.legend(loc='lower left')
plt.grid(True)
plt.show()

# %%
# Assuming baseline_preds, no_noise_preds, pr_auc_preds, and trans_preds are already defined from previous code blocks.
# And y_test is available.

models = {
    'Baseline Model': baseline_preds,
    'Denoising Removed': no_noise_preds,
    'PR AUC as a Loss Function': pr_auc_preds,
    'Transformer Architecture': trans_preds
}

plt.figure(figsize=(10, 8))

for model_name, predictions in models.items():
    fpr, tpr, thresholds = roc_curve(y_test.argmax(axis=1), predictions[:, 1])
    roc_auc = auc(fpr, tpr)
    plt.plot(fpr, tpr, label=f'{model_name} (AUC = {roc_auc:.3f})', linewidth=2)

plt.plot([0, 1], [0, 1], 'k--', linewidth=2)  # Diagonal line for random classifier
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curves for Different Models')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.legend(loc='lower right')
plt.grid(True)
plt.show()
